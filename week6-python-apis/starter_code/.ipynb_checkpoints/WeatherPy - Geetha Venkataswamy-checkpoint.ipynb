# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis (Geetha)
# * The weather gets warmer as you approach the equator as proven by the scatter plot charting latitude vs temp. The warmer temps for this set seems to lean towards 20-30 latitude (north of equator)
# * Humidity seems to lean *very* slightly higher north of the equator
# * There is no strong relationship between latitude and wind speed. There seems to be a strong presence of cities in the 1-4 mph range across the board
#
# ---
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json

# Import API key
from api_keys import api_key
#from config import api_key

# Incorporated citipy to determine city based on latitude and longitude
# note: run pip install citipy
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
api_key
# Out:
# '4f4e8ff1e65d570d34f6275958bc9ef1'

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []
countries = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    country = citipy.nearest_city(lat_lng[0], lat_lng[1]).country_code
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)
        countries.append(country)

# Print the city count to confirm sufficient count
no_cities = len(cities)
print ("***" + str(no_cities) + " to be processed***")
# Out:
# ***594 to be processed***

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
ID_df = []
city_df = []
cloud_df = []
country_df = []
date_df = []
humidity_df = []
lat_df = []
lon_df = []
maxtemp_df = []
wind_df = []
error_cities = []
error_countries = []
error_code = []


#for i in cities:
for  i in range(len(cities)) :
    try: 
        c = cities[i]
        print("Processing Record " + str(i) + " of Set 1 | " + c)
        url = "https://api.openweathermap.org/data/2.5/weather?q=" + cities[i] + "," + countries[i]+"&APPID="+ api_key
        JSONContent = requests.get(url).json()
        #JSONContent = requests.get("https://api.openweathermap.org/data/2.5/weather?q=London,uk&APPID=4f4e8ff1e65d570d34f6275958bc9ef1" ).json()
        #print(requests.get(url).json())
        ID_df.append(JSONContent['id'])
        city_df.append(JSONContent['name'])
        cloud_df.append(JSONContent['clouds']['all'])
        country_df.append(countries[i])
        date_df.append(JSONContent['dt'])
        humidity_df.append(JSONContent['main']['humidity'])
        lat_df.append(JSONContent['coord']['lat'])
        lon_df.append(JSONContent['coord']['lon'])
        maxtemp_df.append((JSONContent['main']['temp_max']) * (9/5) - (459.67))
        wind_df.append(JSONContent['wind']['speed'])
    except: 
        error_cities.append(cities[i])
        error_countries.append(countries[i])
        error_code.append(requests.get(url2).json())
        print("****Failed**** Processing Record " + str(i) + " of Set 1 | " + c)
# Out:
# Processing Record 0 of Set 1 | sterling
# Processing Record 1 of Set 1 | hasaki
# Processing Record 2 of Set 1 | albany
# Processing Record 3 of Set 1 | hilo
# Processing Record 4 of Set 1 | mokhsogollokh
# Processing Record 5 of Set 1 | lebu
# Processing Record 6 of Set 1 | ushuaia
# Processing Record 7 of Set 1 | atuona
# Processing Record 8 of Set 1 | coahuayana
# Processing Record 9 of Set 1 | saint-philippe
# Processing Record 10 of Set 1 | grindavik
# Processing Record 11 of Set 1 | kawalu
# Processing Record 12 of Set 1 | jerome
# Processing Record 13 of Set 1 | vaini
# Processing Record 14 of Set 1 | chokurdakh
# Processing Record 15 of Set 1 | mufulira
# Processing Record 16 of Set 1 | georgetown
# Processing Record 17 of Set 1 | severo-kurilsk
# Processing Record 18 of Set 1 | onalaska
# Processing Record 19 of Set 1 | waiouru
# Processing Record 20 of Set 1 | saint george
# Processing Record 21 of Set 1 | port alfred
# Processing Record 22 of Set 1 | jaciara
# Processing Record 23 of Set 1 | cape town
# Processing Record 24 of Set 1 | talnakh
# Processing Record 25 of Set 1 | kapaa
# Processing Record 26 of Set 1 | hithadhoo
# Processing Record 27 of Set 1 | qaanaaq
# Processing Record 28 of Set 1 | nelson bay
# Processing Record 29 of Set 1 | ligayan
# Processing Record 30 of Set 1 | asau
# ****Failed**** Processing Record 30 of Set 1 | asau
# Processing Record 31 of Set 1 | the valley
# Processing Record 32 of Set 1 | omboue
# Processing Record 33 of Set 1 | thompson
# Processing Record 34 of Set 1 | tasiilaq
# Processing Record 35 of Set 1 | busselton
# Processing Record 36 of Set 1 | rikitea
# Processing Record 37 of Set 1 | illoqqortoormiut
# ****Failed**** Processing Record 37 of Set 1 | illoqqortoormiut
# Processing Record 38 of Set 1 | kavaratti
# Processing Record 39 of Set 1 | esperance
# Processing Record 40 of Set 1 | charleston
# Processing Record 41 of Set 1 | kutulik
# Processing Record 42 of Set 1 | kamenskoye
# ****Failed**** Processing Record 42 of Set 1 | kamenskoye
# Processing Record 43 of Set 1 | ljubimec
# ****Failed**** Processing Record 43 of Set 1 | ljubimec
# Processing Record 44 of Set 1 | maniitsoq
# Processing Record 45 of Set 1 | belushya guba
# ****Failed**** Processing Record 45 of Set 1 | belushya guba
# Processing Record 46 of Set 1 | cockburn town
# Processing Record 47 of Set 1 | tuktoyaktuk
# Processing Record 48 of Set 1 | havelock
# Processing Record 49 of Set 1 | caravelas
# Processing Record 50 of Set 1 | grand river south east
# ****Failed**** Processing Record 50 of Set 1 | grand river south east
# Processing Record 51 of Set 1 | taolanaro
# ****Failed**** Processing Record 51 of Set 1 | taolanaro
# Processing Record 52 of Set 1 | tiksi
# Processing Record 53 of Set 1 | cazaje
# ****Failed**** Processing Record 53 of Set 1 | cazaje
# Processing Record 54 of Set 1 | ponta delgada
# Processing Record 55 of Set 1 | leningradskiy
# Processing Record 56 of Set 1 | avera
# ****Failed**** Processing Record 56 of Set 1 | avera
# Processing Record 57 of Set 1 | mataura
# ****Failed**** Processing Record 57 of Set 1 | mataura
# Processing Record 58 of Set 1 | jamestown
# Processing Record 59 of Set 1 | saint-francois
# Processing Record 60 of Set 1 | cidreira
# Processing Record 61 of Set 1 | touros
# Processing Record 62 of Set 1 | cam ranh
# Processing Record 63 of Set 1 | kropotkin
# Processing Record 64 of Set 1 | puerto ayora
# Processing Record 65 of Set 1 | kulhudhuffushi
# Processing Record 66 of Set 1 | victoria
# Processing Record 67 of Set 1 | carmen
# ****Failed**** Processing Record 67 of Set 1 | carmen
# Processing Record 68 of Set 1 | tsihombe
# ****Failed**** Processing Record 68 of Set 1 | tsihombe
# Processing Record 69 of Set 1 | ribeira grande
# Processing Record 70 of Set 1 | huangyan
# ****Failed**** Processing Record 70 of Set 1 | huangyan
# Processing Record 71 of Set 1 | bengkulu
# ****Failed**** Processing Record 71 of Set 1 | bengkulu
# Processing Record 72 of Set 1 | kieta
# Processing Record 73 of Set 1 | sur
# Processing Record 74 of Set 1 | lipin bor
# Processing Record 75 of Set 1 | bluff
# Processing Record 76 of Set 1 | tual
# Processing Record 77 of Set 1 | cheuskiny
# ****Failed**** Processing Record 77 of Set 1 | cheuskiny
# Processing Record 78 of Set 1 | yaya
# Processing Record 79 of Set 1 | arraial do cabo
# Processing Record 80 of Set 1 | ondjiva
# Processing Record 81 of Set 1 | likasi
# Processing Record 82 of Set 1 | geraldton
# Processing Record 83 of Set 1 | kutum
# Processing Record 84 of Set 1 | tigil
# Processing Record 85 of Set 1 | kitimat
# Processing Record 86 of Set 1 | fare
# Processing Record 87 of Set 1 | waingapu
# Processing Record 88 of Set 1 | port hardy
# Processing Record 89 of Set 1 | punta arenas
# Processing Record 90 of Set 1 | mitsamiouli
# Processing Record 91 of Set 1 | hermanus
# Processing Record 92 of Set 1 | middlesbrough
# Processing Record 93 of Set 1 | cherskiy
# Processing Record 94 of Set 1 | iqaluit
# Processing Record 95 of Set 1 | shushtar
# Processing Record 96 of Set 1 | yacuiba
# Processing Record 97 of Set 1 | damaturu
# Processing Record 98 of Set 1 | mar del plata
# Processing Record 99 of Set 1 | tukrah
# ****Failed**** Processing Record 99 of Set 1 | tukrah
# Processing Record 100 of Set 1 | palauig
# Processing Record 101 of Set 1 | khatanga
# Processing Record 102 of Set 1 | barrow
# Processing Record 103 of Set 1 | toliary
# ****Failed**** Processing Record 103 of Set 1 | toliary
# Processing Record 104 of Set 1 | miyang
# Processing Record 105 of Set 1 | saskylakh
# Processing Record 106 of Set 1 | upernavik
# Processing Record 107 of Set 1 | gweta
# Processing Record 108 of Set 1 | butaritari
# Processing Record 109 of Set 1 | port-gentil
# Processing Record 110 of Set 1 | airai
# ****Failed**** Processing Record 110 of Set 1 | airai
# Processing Record 111 of Set 1 | dolores
# Processing Record 112 of Set 1 | chuy
# Processing Record 113 of Set 1 | lukulu
# Processing Record 114 of Set 1 | barentsburg
# ****Failed**** Processing Record 114 of Set 1 | barentsburg
# Processing Record 115 of Set 1 | hami
# Processing Record 116 of Set 1 | vestmannaeyjar
# Processing Record 117 of Set 1 | ilulissat
# Processing Record 118 of Set 1 | lata
# ****Failed**** Processing Record 118 of Set 1 | lata
# Processing Record 119 of Set 1 | ottumwa
# Processing Record 120 of Set 1 | bambous virieux
# Processing Record 121 of Set 1 | odweyne
# ****Failed**** Processing Record 121 of Set 1 | odweyne
# Processing Record 122 of Set 1 | yellowknife
# Processing Record 123 of Set 1 | ayan
# ****Failed**** Processing Record 123 of Set 1 | ayan
# Processing Record 124 of Set 1 | kruisfontein
# Processing Record 125 of Set 1 | new norfolk
# Processing Record 126 of Set 1 | auki
# Processing Record 127 of Set 1 | carnarvon
# Processing Record 128 of Set 1 | ostrovnoy
# Processing Record 129 of Set 1 | praia
# Processing Record 130 of Set 1 | nizwa
# Processing Record 131 of Set 1 | hobyo
# Processing Record 132 of Set 1 | quatre cocos
# Processing Record 133 of Set 1 | samarai
# Processing Record 134 of Set 1 | bethel
# Processing Record 135 of Set 1 | hambantota
# Processing Record 136 of Set 1 | pangnirtung
# Processing Record 137 of Set 1 | codrington
# ****Failed**** Processing Record 137 of Set 1 | codrington
# Processing Record 138 of Set 1 | saldanha
# Processing Record 139 of Set 1 | aswan
# Processing Record 140 of Set 1 | ponta do sol
# Processing Record 141 of Set 1 | dikson
# Processing Record 142 of Set 1 | kjollefjord
# Processing Record 143 of Set 1 | petropavlovsk-kamchatskiy
# Processing Record 144 of Set 1 | aljezur
# Processing Record 145 of Set 1 | provideniya
# Processing Record 146 of Set 1 | yulara
# Processing Record 147 of Set 1 | norman wells
# Processing Record 148 of Set 1 | muros
# Processing Record 149 of Set 1 | bandarbeyla
# Processing Record 150 of Set 1 | faya
# ****Failed**** Processing Record 150 of Set 1 | faya
# Processing Record 151 of Set 1 | konstantinovka
# Processing Record 152 of Set 1 | samusu
# ****Failed**** Processing Record 152 of Set 1 | samusu
# Processing Record 153 of Set 1 | indian head
# Processing Record 154 of Set 1 | itarema
# Processing Record 155 of Set 1 | katesh
# Processing Record 156 of Set 1 | hobart
# Processing Record 157 of Set 1 | nikolskoye
# Processing Record 158 of Set 1 | nagua
# Processing Record 159 of Set 1 | saint-pascal
# ****Failed**** Processing Record 159 of Set 1 | saint-pascal
# Processing Record 160 of Set 1 | norfolk
# Processing Record 161 of Set 1 | margate
# Processing Record 162 of Set 1 | dmitriyevka
# Processing Record 163 of Set 1 | riverton
# Processing Record 164 of Set 1 | ambulu
# Processing Record 165 of Set 1 | daru
# Processing Record 166 of Set 1 | omsukchan
# Processing Record 167 of Set 1 | lavrentiya
# Processing Record 168 of Set 1 | dzhusaly
# ****Failed**** Processing Record 168 of Set 1 | dzhusaly
# Processing Record 169 of Set 1 | tuatapere
# Processing Record 170 of Set 1 | ust-omchug
# Processing Record 171 of Set 1 | katsuura
# Processing Record 172 of Set 1 | yar-sale
# Processing Record 173 of Set 1 | coquimbo
# Processing Record 174 of Set 1 | prince rupert
# Processing Record 175 of Set 1 | avarua
# Processing Record 176 of Set 1 | zyryanka
# Processing Record 177 of Set 1 | gerash
# Processing Record 178 of Set 1 | port arthur
# Processing Record 179 of Set 1 | kenai
# Processing Record 180 of Set 1 | oranjemund
# Processing Record 181 of Set 1 | kaitangata
# Processing Record 182 of Set 1 | bredasdorp
# Processing Record 183 of Set 1 | faanui
# Processing Record 184 of Set 1 | nhulunbuy
# Processing Record 185 of Set 1 | whitehorse
# Processing Record 186 of Set 1 | bolshoy lug
# Processing Record 187 of Set 1 | farmington
# Processing Record 188 of Set 1 | galiwinku
# ****Failed**** Processing Record 188 of Set 1 | galiwinku
# Processing Record 189 of Set 1 | dalby
# Processing Record 190 of Set 1 | stillwater
# Processing Record 191 of Set 1 | torbay
# Processing Record 192 of Set 1 | salym
# Processing Record 193 of Set 1 | bolungarvik
# ****Failed**** Processing Record 193 of Set 1 | bolungarvik
# Processing Record 194 of Set 1 | orange cove
# Processing Record 195 of Set 1 | north branch
# Processing Record 196 of Set 1 | atar
# Processing Record 197 of Set 1 | mahebourg
# Processing Record 198 of Set 1 | kavieng
# Processing Record 199 of Set 1 | vaitupu
# ****Failed**** Processing Record 199 of Set 1 | vaitupu
# Processing Record 200 of Set 1 | korla
# Processing Record 201 of Set 1 | eenhana
# Processing Record 202 of Set 1 | kodiak
# Processing Record 203 of Set 1 | constitucion
# Processing Record 204 of Set 1 | ixtapa
# Processing Record 205 of Set 1 | clinton
# Processing Record 206 of Set 1 | thabazimbi
# Processing Record 207 of Set 1 | balao
# Processing Record 208 of Set 1 | mahadday weyne
# ****Failed**** Processing Record 208 of Set 1 | mahadday weyne
# Processing Record 209 of Set 1 | guanare
# Processing Record 210 of Set 1 | vardo
# Processing Record 211 of Set 1 | san carlos de bariloche
# Processing Record 212 of Set 1 | bonthe
# Processing Record 213 of Set 1 | pemangkat
# ****Failed**** Processing Record 213 of Set 1 | pemangkat
# Processing Record 214 of Set 1 | cayenne
# Processing Record 215 of Set 1 | souillac
# Processing Record 216 of Set 1 | sao felix do xingu
# Processing Record 217 of Set 1 | utiel
# Processing Record 218 of Set 1 | hashtrud
# Processing Record 219 of Set 1 | inhambane
# Processing Record 220 of Set 1 | kuusamo
# Processing Record 221 of Set 1 | vikhorevka
# Processing Record 222 of Set 1 | luderitz
# Processing Record 223 of Set 1 | saint-michel-des-saints
# Processing Record 224 of Set 1 | kidal
# Processing Record 225 of Set 1 | catio
# Processing Record 226 of Set 1 | kloulklubed
# Processing Record 227 of Set 1 | clyde river
# Processing Record 228 of Set 1 | marsa matruh
# Processing Record 229 of Set 1 | clonakilty
# Processing Record 230 of Set 1 | isangel
# Processing Record 231 of Set 1 | rostusa
# ****Failed**** Processing Record 231 of Set 1 | rostusa
# Processing Record 232 of Set 1 | srednekolymsk
# Processing Record 233 of Set 1 | saint-gedeon
# Processing Record 234 of Set 1 | aasiaat
# Processing Record 235 of Set 1 | panambi
# Processing Record 236 of Set 1 | necochea
# Processing Record 237 of Set 1 | along
# Processing Record 238 of Set 1 | halol
# Processing Record 239 of Set 1 | itirapina
# Processing Record 240 of Set 1 | roald
# Processing Record 241 of Set 1 | vestmanna
# Processing Record 242 of Set 1 | hualmay
# Processing Record 243 of Set 1 | paramonga
# Processing Record 244 of Set 1 | nizhneyansk
# ****Failed**** Processing Record 244 of Set 1 | nizhneyansk
# Processing Record 245 of Set 1 | kaohsiung
# Processing Record 246 of Set 1 | bismarck
# Processing Record 247 of Set 1 | stokmarknes
# Processing Record 248 of Set 1 | longyearbyen
# Processing Record 249 of Set 1 | kununurra
# Processing Record 250 of Set 1 | kahului
# Processing Record 251 of Set 1 | shkotovo-26
# ****Failed**** Processing Record 251 of Set 1 | shkotovo-26
# Processing Record 252 of Set 1 | gunnedah
# Processing Record 253 of Set 1 | honiara
# Processing Record 254 of Set 1 | shkotovo-22
# ****Failed**** Processing Record 254 of Set 1 | shkotovo-22
# Processing Record 255 of Set 1 | nouadhibou
# Processing Record 256 of Set 1 | dhidhdhoo
# Processing Record 257 of Set 1 | narsaq
# Processing Record 258 of Set 1 | namibe
# Processing Record 259 of Set 1 | saint anthony
# ****Failed**** Processing Record 259 of Set 1 | saint anthony
# Processing Record 260 of Set 1 | berekum
# Processing Record 261 of Set 1 | castro
# Processing Record 262 of Set 1 | high prairie
# Processing Record 263 of Set 1 | turukhansk
# Processing Record 264 of Set 1 | sorland
# Processing Record 265 of Set 1 | alta floresta
# Processing Record 266 of Set 1 | san quintin
# ****Failed**** Processing Record 266 of Set 1 | san quintin
# Processing Record 267 of Set 1 | jalingo
# Processing Record 268 of Set 1 | llanes
# Processing Record 269 of Set 1 | aksarka
# Processing Record 270 of Set 1 | effingham
# Processing Record 271 of Set 1 | antofagasta
# Processing Record 272 of Set 1 | westport
# Processing Record 273 of Set 1 | arkhangelsk
# Processing Record 274 of Set 1 | kamaishi
# Processing Record 275 of Set 1 | male
# Processing Record 276 of Set 1 | khani
# ****Failed**** Processing Record 276 of Set 1 | khani
# Processing Record 277 of Set 1 | halalo
# ****Failed**** Processing Record 277 of Set 1 | halalo
# Processing Record 278 of Set 1 | asfi
# ****Failed**** Processing Record 278 of Set 1 | asfi
# Processing Record 279 of Set 1 | tura
# Processing Record 280 of Set 1 | lagoa
# Processing Record 281 of Set 1 | deputatskiy
# Processing Record 282 of Set 1 | mahajanga
# Processing Record 283 of Set 1 | hearst
# Processing Record 284 of Set 1 | mansar
# Processing Record 285 of Set 1 | salalah
# Processing Record 286 of Set 1 | tornio
# Processing Record 287 of Set 1 | pevek
# Processing Record 288 of Set 1 | russell
# Processing Record 289 of Set 1 | yuryuzan
# Processing Record 290 of Set 1 | ancud
# Processing Record 291 of Set 1 | sentyabrskiy
# ****Failed**** Processing Record 291 of Set 1 | sentyabrskiy
# Processing Record 292 of Set 1 | bengkalis
# ****Failed**** Processing Record 292 of Set 1 | bengkalis
# Processing Record 293 of Set 1 | carutapera
# Processing Record 294 of Set 1 | kokuy
# Processing Record 295 of Set 1 | lorengau
# Processing Record 296 of Set 1 | verkhoyansk
# Processing Record 297 of Set 1 | arlit
# Processing Record 298 of Set 1 | moose factory
# Processing Record 299 of Set 1 | amapa
# Processing Record 300 of Set 1 | peterborough
# Processing Record 301 of Set 1 | patzcuaro
# Processing Record 302 of Set 1 | ramhormoz
# Processing Record 303 of Set 1 | zorritos
# Processing Record 304 of Set 1 | praia da vitoria
# Processing Record 305 of Set 1 | brae
# Processing Record 306 of Set 1 | san patricio
# Processing Record 307 of Set 1 | hay river
# Processing Record 308 of Set 1 | gasa
# Processing Record 309 of Set 1 | vila velha
# Processing Record 310 of Set 1 | peterhead
# Processing Record 311 of Set 1 | vologda
# Processing Record 312 of Set 1 | kirakira
# Processing Record 313 of Set 1 | santa fe
# Processing Record 314 of Set 1 | safaga
# ****Failed**** Processing Record 314 of Set 1 | safaga
# Processing Record 315 of Set 1 | hellin
# Processing Record 316 of Set 1 | marawi
# Processing Record 317 of Set 1 | seoul
# Processing Record 318 of Set 1 | banda aceh
# Processing Record 319 of Set 1 | ekibastuz
# Processing Record 320 of Set 1 | guerrero negro
# Processing Record 321 of Set 1 | houlton
# Processing Record 322 of Set 1 | sao mateus
# Processing Record 323 of Set 1 | berbera
# Processing Record 324 of Set 1 | bairiki
# ****Failed**** Processing Record 324 of Set 1 | bairiki
# Processing Record 325 of Set 1 | dajal
# Processing Record 326 of Set 1 | tessalit
# Processing Record 327 of Set 1 | lincoln
# Processing Record 328 of Set 1 | dingle
# Processing Record 329 of Set 1 | vila do maio
# Processing Record 330 of Set 1 | beloha
# Processing Record 331 of Set 1 | sharjah
# Processing Record 332 of Set 1 | pisco
# Processing Record 333 of Set 1 | evensk
# Processing Record 334 of Set 1 | mount gambier
# Processing Record 335 of Set 1 | suhbaatar
# Processing Record 336 of Set 1 | meulaboh
# Processing Record 337 of Set 1 | cabo san lucas
# Processing Record 338 of Set 1 | bara
# ****Failed**** Processing Record 338 of Set 1 | bara
# Processing Record 339 of Set 1 | kiama
# Processing Record 340 of Set 1 | kisangani
# Processing Record 341 of Set 1 | warqla
# ****Failed**** Processing Record 341 of Set 1 | warqla
# Processing Record 342 of Set 1 | udachnyy
# Processing Record 343 of Set 1 | port blair
# Processing Record 344 of Set 1 | palabuhanratu
# ****Failed**** Processing Record 344 of Set 1 | palabuhanratu
# Processing Record 345 of Set 1 | santiago del estero
# Processing Record 346 of Set 1 | belaya gora
# Processing Record 347 of Set 1 | zavyalovo
# Processing Record 348 of Set 1 | khvoynaya
# Processing Record 349 of Set 1 | jumla
# Processing Record 350 of Set 1 | banmo
# ****Failed**** Processing Record 350 of Set 1 | banmo
# Processing Record 351 of Set 1 | keokuk
# Processing Record 352 of Set 1 | baykit
# Processing Record 353 of Set 1 | tabiauea
# ****Failed**** Processing Record 353 of Set 1 | tabiauea
# Processing Record 354 of Set 1 | padang
# Processing Record 355 of Set 1 | ontario
# Processing Record 356 of Set 1 | erenhot
# Processing Record 357 of Set 1 | nanortalik
# Processing Record 358 of Set 1 | bida
# Processing Record 359 of Set 1 | nuuk
# Processing Record 360 of Set 1 | krasnoselkup
# ****Failed**** Processing Record 360 of Set 1 | krasnoselkup
# Processing Record 361 of Set 1 | sarahan
# Processing Record 362 of Set 1 | clarence town
# Processing Record 363 of Set 1 | urucui
# Processing Record 364 of Set 1 | saleaula
# ****Failed**** Processing Record 364 of Set 1 | saleaula
# Processing Record 365 of Set 1 | polistena
# Processing Record 366 of Set 1 | kamina
# Processing Record 367 of Set 1 | mildura
# Processing Record 368 of Set 1 | mansa
# Processing Record 369 of Set 1 | aklavik
# Processing Record 370 of Set 1 | lompoc
# Processing Record 371 of Set 1 | mys shmidta
# ****Failed**** Processing Record 371 of Set 1 | mys shmidta
# Processing Record 372 of Set 1 | vavoua
# Processing Record 373 of Set 1 | akdepe
# Processing Record 374 of Set 1 | vao
# Processing Record 375 of Set 1 | tolaga bay
# Processing Record 376 of Set 1 | malanje
# Processing Record 377 of Set 1 | labuhan
# Processing Record 378 of Set 1 | valparaiso
# Processing Record 379 of Set 1 | grand-lahou
# Processing Record 380 of Set 1 | chikoy
# ****Failed**** Processing Record 380 of Set 1 | chikoy
# Processing Record 381 of Set 1 | yerbogachen
# Processing Record 382 of Set 1 | lasa
# ****Failed**** Processing Record 382 of Set 1 | lasa
# Processing Record 383 of Set 1 | east london
# Processing Record 384 of Set 1 | terney
# Processing Record 385 of Set 1 | qasigiannguit
# Processing Record 386 of Set 1 | sulangan
# Processing Record 387 of Set 1 | sao joao da barra
# Processing Record 388 of Set 1 | port augusta
# Processing Record 389 of Set 1 | bonavista
# Processing Record 390 of Set 1 | kibaya
# Processing Record 391 of Set 1 | bet shemesh
# Processing Record 392 of Set 1 | wanaka
# Processing Record 393 of Set 1 | boa vista
# Processing Record 394 of Set 1 | kijang
# Processing Record 395 of Set 1 | varca
# Processing Record 396 of Set 1 | balkhash
# Processing Record 397 of Set 1 | mazamari
# Processing Record 398 of Set 1 | ewa beach
# Processing Record 399 of Set 1 | college
# Processing Record 400 of Set 1 | rock sound
# Processing Record 401 of Set 1 | skjervoy
# Processing Record 402 of Set 1 | manali
# Processing Record 403 of Set 1 | athabasca
# Processing Record 404 of Set 1 | nsoko
# Processing Record 405 of Set 1 | flagstaff
# Processing Record 406 of Set 1 | tiarei
# Processing Record 407 of Set 1 | karari
# Processing Record 408 of Set 1 | huarmey
# Processing Record 409 of Set 1 | lilongwe
# Processing Record 410 of Set 1 | mocuba
# Processing Record 411 of Set 1 | naftah
# ****Failed**** Processing Record 411 of Set 1 | naftah
# Processing Record 412 of Set 1 | kayankulam
# Processing Record 413 of Set 1 | alofi
# Processing Record 414 of Set 1 | gat
# ****Failed**** Processing Record 414 of Set 1 | gat
# Processing Record 415 of Set 1 | biloela
# Processing Record 416 of Set 1 | porto belo
# Processing Record 417 of Set 1 | jalu
# Processing Record 418 of Set 1 | corlu
# Processing Record 419 of Set 1 | sobolevo
# Processing Record 420 of Set 1 | tulcingo
# ****Failed**** Processing Record 420 of Set 1 | tulcingo
# Processing Record 421 of Set 1 | bacuit
# ****Failed**** Processing Record 421 of Set 1 | bacuit
# Processing Record 422 of Set 1 | aginskoye
# Processing Record 423 of Set 1 | marcona
# ****Failed**** Processing Record 423 of Set 1 | marcona
# Processing Record 424 of Set 1 | gurgan
# ****Failed**** Processing Record 424 of Set 1 | gurgan
# Processing Record 425 of Set 1 | amderma
# ****Failed**** Processing Record 425 of Set 1 | amderma
# Processing Record 426 of Set 1 | buraydah
# Processing Record 427 of Set 1 | raga
# ****Failed**** Processing Record 427 of Set 1 | raga
# Processing Record 428 of Set 1 | dolbeau
# ****Failed**** Processing Record 428 of Set 1 | dolbeau
# Processing Record 429 of Set 1 | iquique
# Processing Record 430 of Set 1 | ucluelet
# Processing Record 431 of Set 1 | maceio
# Processing Record 432 of Set 1 | dunedin
# Processing Record 433 of Set 1 | saint-pierre
# Processing Record 434 of Set 1 | stolin
# Processing Record 435 of Set 1 | sitka
# Processing Record 436 of Set 1 | chapais
# Processing Record 437 of Set 1 | ausa
# Processing Record 438 of Set 1 | nome
# Processing Record 439 of Set 1 | barcelos
# Processing Record 440 of Set 1 | verkhnevilyuysk
# Processing Record 441 of Set 1 | paamiut
# Processing Record 442 of Set 1 | hede
# Processing Record 443 of Set 1 | berlevag
# Processing Record 444 of Set 1 | jangaon
# Processing Record 445 of Set 1 | taseyevo
# Processing Record 446 of Set 1 | helong
# Processing Record 447 of Set 1 | kankon
# Processing Record 448 of Set 1 | puerto del rosario
# Processing Record 449 of Set 1 | pacific grove
# Processing Record 450 of Set 1 | gornyak
# Processing Record 451 of Set 1 | peniche
# Processing Record 452 of Set 1 | terrace
# Processing Record 453 of Set 1 | la rioja
# Processing Record 454 of Set 1 | rolim de moura
# ****Failed**** Processing Record 454 of Set 1 | rolim de moura
# Processing Record 455 of Set 1 | sao filipe
# Processing Record 456 of Set 1 | qurbus
# Processing Record 457 of Set 1 | hamilton
# Processing Record 458 of Set 1 | caluquembe
# Processing Record 459 of Set 1 | stornoway
# Processing Record 460 of Set 1 | bagdarin
# Processing Record 461 of Set 1 | dosso
# Processing Record 462 of Set 1 | progreso
# Processing Record 463 of Set 1 | biu
# Processing Record 464 of Set 1 | henties bay
# Processing Record 465 of Set 1 | port elizabeth
# Processing Record 466 of Set 1 | poum
# Processing Record 467 of Set 1 | port lincoln
# Processing Record 468 of Set 1 | berdigestyakh
# Processing Record 469 of Set 1 | nova vicosa
# Processing Record 470 of Set 1 | korgoz
# Processing Record 471 of Set 1 | sinjar
# Processing Record 472 of Set 1 | buala
# Processing Record 473 of Set 1 | rocha
# Processing Record 474 of Set 1 | roros
# Processing Record 475 of Set 1 | itacarambi
# Processing Record 476 of Set 1 | ellensburg
# Processing Record 477 of Set 1 | jackson
# Processing Record 478 of Set 1 | fairview
# Processing Record 479 of Set 1 | rawannawi
# ****Failed**** Processing Record 479 of Set 1 | rawannawi
# Processing Record 480 of Set 1 | maniwaki
# Processing Record 481 of Set 1 | santa quiteria do maranhao
# Processing Record 482 of Set 1 | nishihara
# Processing Record 483 of Set 1 | balikpapan
# Processing Record 484 of Set 1 | chor
# Processing Record 485 of Set 1 | acari
# Processing Record 486 of Set 1 | aldan
# Processing Record 487 of Set 1 | preobrazheniye
# Processing Record 488 of Set 1 | kazalinsk
# ****Failed**** Processing Record 488 of Set 1 | kazalinsk
# Processing Record 489 of Set 1 | frome
# Processing Record 490 of Set 1 | klaksvik
# Processing Record 491 of Set 1 | naryan-mar
# Processing Record 492 of Set 1 | ploufragan
# Processing Record 493 of Set 1 | bulgan
# Processing Record 494 of Set 1 | harper
# Processing Record 495 of Set 1 | tawkar
# ****Failed**** Processing Record 495 of Set 1 | tawkar
# Processing Record 496 of Set 1 | zhigansk
# Processing Record 497 of Set 1 | gangotri
# ****Failed**** Processing Record 497 of Set 1 | gangotri
# Processing Record 498 of Set 1 | mantena
# Processing Record 499 of Set 1 | nalut
# Processing Record 500 of Set 1 | tautira
# Processing Record 501 of Set 1 | vanavara
# Processing Record 502 of Set 1 | tinsukia
# Processing Record 503 of Set 1 | attawapiskat
# ****Failed**** Processing Record 503 of Set 1 | attawapiskat
# Processing Record 504 of Set 1 | flinders
# Processing Record 505 of Set 1 | timon
# Processing Record 506 of Set 1 | sompeta
# Processing Record 507 of Set 1 | woodstock
# Processing Record 508 of Set 1 | sorvag
# ****Failed**** Processing Record 508 of Set 1 | sorvag
# Processing Record 509 of Set 1 | stara vyzhivka
# Processing Record 510 of Set 1 | sukhobezvodnoye
# Processing Record 511 of Set 1 | dali
# Processing Record 512 of Set 1 | kota belud
# Processing Record 513 of Set 1 | tumannyy
# ****Failed**** Processing Record 513 of Set 1 | tumannyy
# Processing Record 514 of Set 1 | san cristobal
# Processing Record 515 of Set 1 | bathsheba
# Processing Record 516 of Set 1 | komsomolskiy
# Processing Record 517 of Set 1 | schiedam
# Processing Record 518 of Set 1 | eyl
# Processing Record 519 of Set 1 | vila franca do campo
# Processing Record 520 of Set 1 | zhuhai
# Processing Record 521 of Set 1 | patamundai
# Processing Record 522 of Set 1 | yeppoon
# Processing Record 523 of Set 1 | acapulco
# Processing Record 524 of Set 1 | susanville
# Processing Record 525 of Set 1 | san nicolas
# Processing Record 526 of Set 1 | tabou
# Processing Record 527 of Set 1 | taburi
# ****Failed**** Processing Record 527 of Set 1 | taburi
# Processing Record 528 of Set 1 | ongandjera
# Processing Record 529 of Set 1 | svetlogorsk
# Processing Record 530 of Set 1 | okhotsk
# Processing Record 531 of Set 1 | price
# Processing Record 532 of Set 1 | alice town
# Processing Record 533 of Set 1 | ankazoabo
# Processing Record 534 of Set 1 | mukhen
# Processing Record 535 of Set 1 | pittsfield
# Processing Record 536 of Set 1 | sungaipenuh
# Processing Record 537 of Set 1 | egvekinot
# Processing Record 538 of Set 1 | ahipara
# Processing Record 539 of Set 1 | ca mau
# Processing Record 540 of Set 1 | babanusah
# ****Failed**** Processing Record 540 of Set 1 | babanusah
# Processing Record 541 of Set 1 | comodoro rivadavia
# Processing Record 542 of Set 1 | sidi ali
# Processing Record 543 of Set 1 | nargana
# Processing Record 544 of Set 1 | katy
# Processing Record 545 of Set 1 | chauk
# Processing Record 546 of Set 1 | dinguiraye
# Processing Record 547 of Set 1 | saint-georges
# ****Failed**** Processing Record 547 of Set 1 | saint-georges
# Processing Record 548 of Set 1 | slave lake
# Processing Record 549 of Set 1 | plettenberg bay
# Processing Record 550 of Set 1 | taoudenni
# Processing Record 551 of Set 1 | villazon
# ****Failed**** Processing Record 551 of Set 1 | villazon
# Processing Record 552 of Set 1 | broken hill
# Processing Record 553 of Set 1 | niquelandia
# Processing Record 554 of Set 1 | karratha
# Processing Record 555 of Set 1 | neustadt
# Processing Record 556 of Set 1 | corner brook
# Processing Record 557 of Set 1 | serowe
# Processing Record 558 of Set 1 | kingsville
# Processing Record 559 of Set 1 | nowy dwor mazowiecki
# Processing Record 560 of Set 1 | brokopondo
# Processing Record 561 of Set 1 | bokspits
# ****Failed**** Processing Record 561 of Set 1 | bokspits
# Processing Record 562 of Set 1 | laramie
# Processing Record 563 of Set 1 | champerico
# Processing Record 564 of Set 1 | rungata
# ****Failed**** Processing Record 564 of Set 1 | rungata
# Processing Record 565 of Set 1 | sao jose da coroa grande
# Processing Record 566 of Set 1 | los llanos de aridane
# Processing Record 567 of Set 1 | seymchan
# Processing Record 568 of Set 1 | palmer
# Processing Record 569 of Set 1 | maun
# Processing Record 570 of Set 1 | synya
# Processing Record 571 of Set 1 | gargzdai
# Processing Record 572 of Set 1 | nanakuli
# Processing Record 573 of Set 1 | rudbar
# Processing Record 574 of Set 1 | zhanatas
# ****Failed**** Processing Record 574 of Set 1 | zhanatas
# Processing Record 575 of Set 1 | amga
# Processing Record 576 of Set 1 | bowen
# Processing Record 577 of Set 1 | hanna
# Processing Record 578 of Set 1 | baturite
# ****Failed**** Processing Record 578 of Set 1 | baturite
# Processing Record 579 of Set 1 | leshukonskoye
# Processing Record 580 of Set 1 | oudtshoorn
# Processing Record 581 of Set 1 | la ronge
# Processing Record 582 of Set 1 | upington
# Processing Record 583 of Set 1 | kalokhorion
# ****Failed**** Processing Record 583 of Set 1 | kalokhorion
# Processing Record 584 of Set 1 | fortuna
# Processing Record 585 of Set 1 | simao
# Processing Record 586 of Set 1 | syracuse
# ****Failed**** Processing Record 586 of Set 1 | syracuse
# Processing Record 587 of Set 1 | luau
# Processing Record 588 of Set 1 | olafsvik
# ****Failed**** Processing Record 588 of Set 1 | olafsvik
# Processing Record 589 of Set 1 | pekan
# Processing Record 590 of Set 1 | akhtubinsk
# Processing Record 591 of Set 1 | umm kaddadah
# Processing Record 592 of Set 1 | aleksandrovsk-sakhalinskiy
# Processing Record 593 of Set 1 | mezhdurechensk

# %%
data1 = {"City": error_cities, "Country": error_countries, "Error Code": error_code}
error_df = pd.DataFrame(data1) 
error_df.to_csv(r'ErredRows_Geetha.csv')
error_df
# Out:
#                       City Country  \
# 0                     asau      tv
# 1         illoqqortoormiut      gl
# 2               kamenskoye      ru
# 3                 ljubimec      bg
# 4            belushya guba      ru
# 5   grand river south east      mu
# 6                taolanaro      mg
# 7                   cazaje      ao
# 8                    avera      pf
# 9                  mataura      pf
# 10                  carmen      mx
# 11                tsihombe      mg
# 12                huangyan      cn
# 13                bengkulu      id
# 14               cheuskiny      ru
# 15                  tukrah      ly
# 16                 toliary      mg
# 17                   airai      pw
# 18             barentsburg      sj
# 19                    lata      sb
# 20                 odweyne      so
# 21                    ayan      ru
# 22              codrington      ag
# 23                    faya      td
# 24                  samusu      ws
# 25            saint-pascal      ca
# 26                dzhusaly      kz
# 27               galiwinku      au
# 28             bolungarvik      is
# 29                 vaitupu      wf
# ..                     ...     ...
# 53                  chikoy      ru
# 54                    lasa      cn
# 55                  naftah      tn
# 56                     gat      ly
# 57                tulcingo      mx
# 58                  bacuit      ph
# 59                 marcona      pe
# 60                  gurgan      az
# 61                 amderma      ru
# 62                    raga      sd
# 63                 dolbeau      ca
# 64          rolim de moura      br
# 65               rawannawi      ki
# 66               kazalinsk      kz
# 67                  tawkar      sd
# 68                gangotri      in
# 69            attawapiskat      ca
# 70                  sorvag      fo
# 71                tumannyy      ru
# 72                  taburi      ph
# 73               babanusah      sd
# 74           saint-georges      gf
# 75                villazon      bo
# 76                bokspits      bw
# 77                 rungata      ki
# 78                zhanatas      kz
# 79                baturite      br
# 80             kalokhorion      gr
# 81                syracuse      it
# 82                olafsvik      is
#
#                                      Error Code
# 0   {'cod': '404', 'message': 'city not found'}
# 1   {'cod': '404', 'message': 'city not found'}
# 2   {'cod': '404', 'message': 'city not found'}
# 3   {'cod': '404', 'message': 'city not found'}
# 4   {'cod': '404', 'message': 'city not found'}
# 5   {'cod': '404', 'message': 'city not found'}
# 6   {'cod': '404', 'message': 'city not found'}
# 7   {'cod': '404', 'message': 'city not found'}
# 8   {'cod': '404', 'message': 'city not found'}
# 9   {'cod': '404', 'message': 'city not found'}
# 10  {'cod': '404', 'message': 'city not found'}
# 11  {'cod': '404', 'message': 'city not found'}
# 12  {'cod': '404', 'message': 'city not found'}
# 13  {'cod': '404', 'message': 'city not found'}
# 14  {'cod': '404', 'message': 'city not found'}
# 15  {'cod': '404', 'message': 'city not found'}
# 16  {'cod': '404', 'message': 'city not found'}
# 17  {'cod': '404', 'message': 'city not found'}
# 18  {'cod': '404', 'message': 'city not found'}
# 19  {'cod': '404', 'message': 'city not found'}
# 20  {'cod': '404', 'message': 'city not found'}
# 21  {'cod': '404', 'message': 'city not found'}
# 22  {'cod': '404', 'message': 'city not found'}
# 23  {'cod': '404', 'message': 'city not found'}
# 24  {'cod': '404', 'message': 'city not found'}
# 25  {'cod': '404', 'message': 'city not found'}
# 26  {'cod': '404', 'message': 'city not found'}
# 27  {'cod': '404', 'message': 'city not found'}
# 28  {'cod': '404', 'message': 'city not found'}
# 29  {'cod': '404', 'message': 'city not found'}
# ..                                          ...
# 53  {'cod': '404', 'message': 'city not found'}
# 54  {'cod': '404', 'message': 'city not found'}
# 55  {'cod': '404', 'message': 'city not found'}
# 56  {'cod': '404', 'message': 'city not found'}
# 57  {'cod': '404', 'message': 'city not found'}
# 58  {'cod': '404', 'message': 'city not found'}
# 59  {'cod': '404', 'message': 'city not found'}
# 60  {'cod': '404', 'message': 'city not found'}
# 61  {'cod': '404', 'message': 'city not found'}
# 62  {'cod': '404', 'message': 'city not found'}
# 63  {'cod': '404', 'message': 'city not found'}
# 64  {'cod': '404', 'message': 'city not found'}
# 65  {'cod': '404', 'message': 'city not found'}
# 66  {'cod': '404', 'message': 'city not found'}
# 67  {'cod': '404', 'message': 'city not found'}
# 68  {'cod': '404', 'message': 'city not found'}
# 69  {'cod': '404', 'message': 'city not found'}
# 70  {'cod': '404', 'message': 'city not found'}
# 71  {'cod': '404', 'message': 'city not found'}
# 72  {'cod': '404', 'message': 'city not found'}
# 73  {'cod': '404', 'message': 'city not found'}
# 74  {'cod': '404', 'message': 'city not found'}
# 75  {'cod': '404', 'message': 'city not found'}
# 76  {'cod': '404', 'message': 'city not found'}
# 77  {'cod': '404', 'message': 'city not found'}
# 78  {'cod': '404', 'message': 'city not found'}
# 79  {'cod': '404', 'message': 'city not found'}
# 80  {'cod': '404', 'message': 'city not found'}
# 81  {'cod': '404', 'message': 'city not found'}
# 82  {'cod': '404', 'message': 'city not found'}
#
# [83 rows x 3 columns]

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
data = {"City ID": ID_df, "City": city_df, "Cloudiness": cloud_df, "Country": country_df, "Date": date_df, "Humidity": humidity_df, "Lat": lat_df, "Lng": lon_df, "Max Temp": maxtemp_df, "Wind Speed": wind_df}
weather_df = pd.DataFrame(data) 
weather_df.head()
weather_df.to_csv(r'Weather_Geetha.csv')

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
x = weather_df["Lat"].values
y = weather_df["Max Temp"].values

plt.scatter(x, y,c="skyblue",linewidth=.5, edgecolors="black")

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.title("City Latitude vs Max Temperature")

plt.grid(True)
plt.show()

# Save Figure
from io import BytesIO
f = BytesIO()
plt.savefig(f, format="svg")

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
x = weather_df["Lat"].values
y = weather_df["Humidity"].values

plt.scatter(x, y,c="skyblue",linewidth=.5, edgecolors="black")

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.title("City Latitude vs Humidity")

plt.grid(True)
plt.show()

# Save Figure
from io import BytesIO
f = BytesIO()
plt.savefig(f, format="svg")

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
x = weather_df["Lat"].values
y = weather_df["Cloudiness"].values

plt.scatter(x, y,c="skyblue",linewidth=.5, edgecolors="black")

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.title("City Latitude vs Cloudiness")

plt.grid(True)
plt.show()

# Save Figure
from io import BytesIO
f = BytesIO()
plt.savefig(f, format="svg")

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
x = weather_df["Lat"].values
y = weather_df["Wind Speed"].values

plt.scatter(x, y,c="skyblue",linewidth=.5, edgecolors="black")

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.title("City Latitude vs Wind Speed")

plt.grid(True)
plt.show()

# Save Figure
from io import BytesIO
f = BytesIO()
plt.savefig(f, format="svg")
