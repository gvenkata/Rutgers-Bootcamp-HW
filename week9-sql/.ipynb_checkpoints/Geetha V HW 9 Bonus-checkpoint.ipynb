# %% [markdown]
# As you examine the data, you are overcome with a creeping suspicion that the dataset is fake. You surmise that your boss handed you spurious data in order to test the data engineering skills of a new employee. To confirm your hunch, you decide to take the following steps to generate a visualization of the data, with which you will confront your boss:
#
# 1. Import the SQL database into Pandas. (Yes, you could read the CSVs directly in Pandas, but you are, after all, trying to prove your technical mettle.) This step may require some research. Feel free to use the code below to get started. Be sure to make any necessary modifications for your username, password, host, port, and database name:
#
# 2. Create a bar chart of average salary by title.
#
# 3. You may also include a technical report in markdown format, in which you outline the data engineering steps taken in the homework assignment.

# %%
import psycopg2 as pg
import pandas.io.sql as psql
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
from sqlalchemy import create_engine
engine = create_engine('postgresql+psycopg2://postgres:FuckOff666!@localhost:5432/GeethaV_HW9')
#engine = create_engine('postgresql+psycopg2://scott:tiger@localhost/mydatabase')
connection = engine.connect()

# %%
vSQL = "SELECT TI.title, round(avg(SA.salary), 2) as MONEY FROM employees as EE, titles as TI, salaries as SA WHERE EE.emp_no = TI.emp_no AND SA.emp_no = EE.emp_no group by TI.title order by MONEY DESC"
df = pd.read_sql_query(vSQL,con=connection)
# Out:
#                 title     money
# 0        Senior Staff  58503.29
# 1               Staff  58465.27
# 2             Manager  51531.04
# 3    Technique Leader  48580.51
# 4            Engineer  48539.78
# 5     Senior Engineer  48506.75
# 6  Assistant Engineer  48493.20

# %%
money = df["money"].values
titles = df["title"].values

plt.bar(titles, money, color='r', alpha=0.5, align="center")
plt.xlabel("Titles")
plt.ylabel("Average Salary")
plt.title("Pewlett Hackard: Average Salaries by Title")

plt.setp(plt.gca().get_xticklabels(),rotation=45, horizontalalignment='right')
plt.show()
