# %%
import http.client

conn = http.client.HTTPSConnection("api.sportradar.us")

conn.request("GET", "/nfl/official/trial/v5/en/league/hierarchy.json?api_key=e5fcs5mgz2fcmqpc3cmfmqcf")

res = conn.getresponse()
data = res.read()

print(data.decode("utf-8"))
# Out:
# <?xml version="1.0" encoding="UTF-8"?>
# <!-- Generation started @ 2019-06-02 19:54:58 +0000 -->
# <league xmlns="http://feed.elasticstats.com/schema/nfl/premium/hierarchy-v5.0.xsd" id="3c6d318a-6164-4290-9bbc-bf9bb21cc4b8" name="National Football League" alias="NFL">
#   <conference id="1bdefe12-6cb2-4d6a-b208-b04602ae79c3" name="AFC" alias="AFC">
#     <division id="b95cd27d-d631-4fe1-bc05-0ae47fc0b14b" name="AFC East" alias="AFC_EAST">
#       <team id="768c92aa-75ff-4a43-bcc0-f2798c2e1724" name="Bills" market="Buffalo" alias="BUF" sr_id="sr:competitor:4376">
#         <references>
#           <reference id="BUF" origin="gsis"/>
#         </references>
#         <franchise id="26f22bc6-1fb9-4c01-80cc-908342490651" name="Bills" alias="BUF">
#           <references>
#             <reference id="2" origin="gsis"/>
#           </references>
#         </franchise>
# ...
