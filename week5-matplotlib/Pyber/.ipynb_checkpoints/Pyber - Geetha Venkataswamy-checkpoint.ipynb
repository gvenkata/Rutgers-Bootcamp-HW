# %%
# %matplotlib inline
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np



# File to Load (Remember to change these)
city_data_to_load = "data/city_data.csv"
ride_data_to_load = "data/ride_data.csv"

# Read the City and Ride Data
city_data = pd.read_csv(city_data_to_load)
ride_data = pd.read_csv(ride_data_to_load)

# Combine the data into a single dataset
pyber_data_complete = pd.merge(ride_data, city_data, how="left", on=["city", "city"])


# Display the data table for preview
pyber_data_complete.head()
# Out:
#                  city                 date   fare        ride_id  \
# 0  Lake Jonathanshire  2018-01-14 10:14:22  13.83  5739410935873
# 1  South Michelleport  2018-03-04 18:24:09  30.24  2343912425577
# 2  Port Samanthamouth  2018-02-24 04:29:00  33.44  2005065760003
# 3          Rodneyfort  2018-02-10 23:22:03  23.44  5149245426178
# 4          South Jack  2018-03-06 04:28:35  34.58  3908451377344
#
#    driver_count   type
# 0             5  Urban
# 1            72  Urban
# 2            57  Urban
# 3            34  Urban
# 4            46  Urban

# %% [markdown]
# ## Bubble Plot of Ride Sharing Data

# %%
# Obtain the x and y coordinates for each of the three city types
f1 = pyber_data_complete.groupby("city")["fare"].mean().reset_index(name="avg fare")
f1.head()
f2 = pyber_data_complete.groupby("city")["ride_id"].count().reset_index(name="no rides")
f2.head()
f3 = pd.merge(f1, f2)
f3.head()
f4 = pyber_data_complete[["city", "type", "driver_count"]]
f5 = pd.merge(f3, f4)
f5.head()
#f5["color"] = ["light coral" if x =="Urban" else 800 for x in df['Event']] 
f5.loc[f5.type == "Urban", "color"] = "coral"  
f5.loc[f5.type == "Rural", "color"] = "gold"
f5.loc[f5.type == "Suburban", "color"] = "skyblue"  
# Build the scatter plots for each city types
# create data
x = f5["no rides"].values
y = f5["avg fare"].values
z = f5["driver_count"].values
colors = f5["color"].values
labels= f5["type"].values
ride_length = len(x)

fig, ax = plt.subplots()
# use the scatter function
#plt.scatter(x, y, s=z*10,c=colors,linewidth=.5, edgecolors="black", label="test")
#scatter = ax.scatter(x, y, c=colors, s=z*10,linewidth=.5, edgecolors="black")

la1 = f5[f5["color"].isin(["coral"])] 
x1 =  la1["no rides"].values
y1 = la1["avg fare"].values
z1 = la1["driver_count"].values

la2 = f5[f5["color"].isin(["skyblue"])] 
x2 =  la2["no rides"].values
y2 = la2["avg fare"].values
z2 = la2["driver_count"].values

la3 = f5[f5["color"].isin(["gold"])] 
x3 =  la3["no rides"].values
y3 = la3["avg fare"].values
z3 = la3["driver_count"].values


plt.scatter(x1, y1, s=z1*10,c="coral",linewidth=.5, edgecolors="black", label="Urban")
plt.scatter(x2, y2, s=z2*10,c="skyblue",linewidth=.5, edgecolors="black", label="Suburban")
plt.scatter(x3, y3, s=z3*10,c="gold",linewidth=.5, edgecolors="black", label="Rural")

# Incorporate the other graph properties
plt.xlabel("Total Number of Rides (per city)")
plt.ylabel("Average Fare ($)")
plt.title("Pyber Ride Sharing Data 2016")

plt.grid(True)
lgd = plt.legend()
for handle in lgd.legendHandles:
    handle.set_sizes([100.0])

# Incorporate a text label regarding circle size

t = ("Note:\ncircle size correlates with driver count per city")
plt.text(1.05, .5, t, horizontalalignment='left',verticalalignment='center', transform=ax.transAxes, wrap=True)


# Save Figure
from io import BytesIO
f = "pyberbubble.jpg"
plt.savefig(f, format="jpg")

plt.show()

# %% [markdown]
# ## Total Fares by City Type

# %%
# Calculate Type Percents
ff1 = pyber_data_complete.groupby("type")["fare"].sum().reset_index(name="tf")
ff1.head()

tot_fares = pyber_data_complete["fare"].sum()
tot_fares

ff1['pct fare'] = round((ff1['tf']/tot_fares) * 100, 2)
ff1.head()

# Build Pie Chart
sizes = ff1["pct fare"].values
explode = (0, 0, .1)
labels = ff1["type"].values
colors = ["gold", "coral", "skyblue"]
plt.pie(sizes, explode=explode, labels=labels, colors=colors,
        autopct="%1.1f%%", shadow=True, startangle=140)

plt.title("% Total Fares by City Type")


# Save Figure
from io import BytesIO
f = "farepie.jpg"
plt.savefig(f, format="jpg")


plt.show()

# %%
# Show Figure
plt.show()

# %% [markdown]
# ## Total Rides by City Type

# %%
# Calculate Ride Percents
ff1 = pyber_data_complete.groupby("type")["ride_id"].count().reset_index(name="no rides")
ff1.head()

tot_rides = pyber_data_complete["ride_id"].count()
tot_rides

ff1['pct rides'] = round((ff1['no rides']/tot_rides) * 100, 2)
ff1.head()

# Build Pie Chart
sizes = ff1["pct rides"].values
explode = (0, 0, .1)
labels = ff1["type"].values
colors = ["gold", "coral", "skyblue"]
plt.pie(sizes, explode=explode, labels=labels, colors=colors,
        autopct="%1.1f%%", shadow=True, startangle=140)

plt.title("% Total Rides by City Type")

from io import BytesIO
f = "ridepie.jpg"
plt.savefig(f, format="jpg")

plt.show()

# %%
# Show Figure
plt.show()

# %% [markdown]
# ## Total Drivers by City Type

# %%
# Calculate Driver Percents
ff1 = city_data.groupby("type")["driver_count"].sum().reset_index(name="no drivers")
ff1.head()

tot_drivers = city_data["driver_count"].sum()
tot_drivers

ff1['pct drivers'] = round((ff1['no drivers']/tot_drivers) * 100, 2)
ff1.head()

# Build Pie Charts
sizes = ff1["pct drivers"].values
explode = (0, 0,.1)
labels = ff1["type"].values
colors = ["gold", "coral", "skyblue"]
plt.pie(sizes, explode=explode, labels=labels, colors=colors,
        autopct="%1.1f%%", shadow=True, startangle=140)

plt.title("% Total Drivers by City Type")


from io import BytesIO
f = "driverpie.jpg"
plt.savefig(f, format="jpg")

plt.show()

# %%
# Show Figure
plt.show()

# %% [markdown]
# ## Observations
#
# 1) In total, urban areas have markedly more drivers, rides and fare revenue than rural and suburban areas
# <br>
# 2) City by City, there are, for example, urgan areas that have lower ride volume than suburban or rural areas. It might be worth looking into the factors in those suburban areas that may contribute to greater revenue generation to make marketing decisions
