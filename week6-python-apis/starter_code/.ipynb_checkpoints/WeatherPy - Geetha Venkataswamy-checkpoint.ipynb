# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis (Geetha)
# * The weather gets warmer as you approach the equator as proven by the scatter plot charting latitude vs temp. The warmer temps for this set seems to lean towards 20-30 latitude (north of equator)
# * Humidity seems to lean *very* slightly higher north of the equator
# * There is no strong relationship between latitude and wind speed. There seems to be a strong presence of cities in the 1-4 mph range across the board
#
# ---
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json

# Import API key
from api_keys import api_key
#from config import api_key

# Incorporated citipy to determine city based on latitude and longitude
# note: run pip install citipy
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
api_key
# Out:
# '4f4e8ff1e65d570d34f6275958bc9ef1'

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []
countries = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    country = citipy.nearest_city(lat_lng[0], lat_lng[1]).country_code
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)
        countries.append(country)

# Print the city count to confirm sufficient count
no_cities = len(cities)
print ("***" + str(no_cities) + " to be processed***")
# Out:
# ***598 to be processed***

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
ID_df = []
city_df = []
cloud_df = []
country_df = []
date_df = []
humidity_df = []
lat_df = []
lon_df = []
maxtemp_df = []
wind_df = []
error_cities = []
error_countries = []
error_code = []


#for i in cities:
for  i in range(len(cities)) :
    try: 
        c = cities[i]
        print("Processing Record " + str(i) + " of Set 1 | " + c)
        url = "https://api.openweathermap.org/data/2.5/weather?units=imperial&q=" + cities[i] + "," + countries[i]+"&APPID="+ api_key
        JSONContent = requests.get(url).json()
        #JSONContent = requests.get("https://api.openweathermap.org/data/2.5/weather?q=London,uk&APPID=4f4e8ff1e65d570d34f6275958bc9ef1" ).json()
        #print(requests.get(url).json())
        ID_df.append(JSONContent['id'])
        city_df.append(JSONContent['name'])
        cloud_df.append(JSONContent['clouds']['all'])
        country_df.append(countries[i])
        date_df.append(JSONContent['dt'])
        humidity_df.append(JSONContent['main']['humidity'])
        lat_df.append(JSONContent['coord']['lat'])
        lon_df.append(JSONContent['coord']['lon'])
        maxtemp_df.append((JSONContent['main']['temp_max'])) 
        #* (9/5) - (459.67))
        wind_df.append(JSONContent['wind']['speed'])
    except: 
        error_cities.append(cities[i])
        error_countries.append(countries[i])
        error_code.append(requests.get(url).json())
        print("****Failed**** Processing Record " + str(i) + " of Set 1 | " + c)
# Out:
# Processing Record 0 of Set 1 | havre-saint-pierre
# Processing Record 1 of Set 1 | attawapiskat
# ****Failed**** Processing Record 1 of Set 1 | attawapiskat
# Processing Record 2 of Set 1 | bilibino
# Processing Record 3 of Set 1 | lavrentiya
# Processing Record 4 of Set 1 | teslic
# Processing Record 5 of Set 1 | mazyr
# Processing Record 6 of Set 1 | albany
# Processing Record 7 of Set 1 | souillac
# Processing Record 8 of Set 1 | mpongwe
# Processing Record 9 of Set 1 | hazorasp
# Processing Record 10 of Set 1 | coihaique
# Processing Record 11 of Set 1 | ushuaia
# Processing Record 12 of Set 1 | marsh harbour
# Processing Record 13 of Set 1 | novikovo
# Processing Record 14 of Set 1 | saleaula
# ****Failed**** Processing Record 14 of Set 1 | saleaula
# Processing Record 15 of Set 1 | xichang
# Processing Record 16 of Set 1 | mahebourg
# Processing Record 17 of Set 1 | grindavik
# Processing Record 18 of Set 1 | berlevag
# Processing Record 19 of Set 1 | rikitea
# Processing Record 20 of Set 1 | ponta do sol
# Processing Record 21 of Set 1 | avarua
# Processing Record 22 of Set 1 | los cordobas
# Processing Record 23 of Set 1 | ballina
# Processing Record 24 of Set 1 | bluff
# Processing Record 25 of Set 1 | amapa
# Processing Record 26 of Set 1 | bethel
# Processing Record 27 of Set 1 | chagda
# ****Failed**** Processing Record 27 of Set 1 | chagda
# Processing Record 28 of Set 1 | kungurtug
# Processing Record 29 of Set 1 | singaparna
# Processing Record 30 of Set 1 | uige
# Processing Record 31 of Set 1 | punta arenas
# Processing Record 32 of Set 1 | alice springs
# Processing Record 33 of Set 1 | longyearbyen
# Processing Record 34 of Set 1 | mataura
# ****Failed**** Processing Record 34 of Set 1 | mataura
# Processing Record 35 of Set 1 | glenwood springs
# Processing Record 36 of Set 1 | hamilton
# Processing Record 37 of Set 1 | mackenzie
# Processing Record 38 of Set 1 | acapulco
# Processing Record 39 of Set 1 | margate
# Processing Record 40 of Set 1 | tawang
# Processing Record 41 of Set 1 | broken hill
# Processing Record 42 of Set 1 | puerto ayora
# Processing Record 43 of Set 1 | tiksi
# Processing Record 44 of Set 1 | coquimbo
# Processing Record 45 of Set 1 | thompson
# Processing Record 46 of Set 1 | east london
# Processing Record 47 of Set 1 | tuktoyaktuk
# Processing Record 48 of Set 1 | illoqqortoormiut
# ****Failed**** Processing Record 48 of Set 1 | illoqqortoormiut
# Processing Record 49 of Set 1 | port alfred
# Processing Record 50 of Set 1 | vaini
# Processing Record 51 of Set 1 | ouadda
# Processing Record 52 of Set 1 | san andres
# Processing Record 53 of Set 1 | torbay
# Processing Record 54 of Set 1 | mengcheng
# Processing Record 55 of Set 1 | saint-joseph
# Processing Record 56 of Set 1 | kohlu
# Processing Record 57 of Set 1 | kruisfontein
# Processing Record 58 of Set 1 | jamestown
# Processing Record 59 of Set 1 | tasiilaq
# Processing Record 60 of Set 1 | upernavik
# Processing Record 61 of Set 1 | frunzivka
# Processing Record 62 of Set 1 | gillette
# Processing Record 63 of Set 1 | yulara
# Processing Record 64 of Set 1 | kodiak
# Processing Record 65 of Set 1 | busselton
# Processing Record 66 of Set 1 | porto velho
# Processing Record 67 of Set 1 | klaksvik
# Processing Record 68 of Set 1 | cape town
# Processing Record 69 of Set 1 | pitimbu
# Processing Record 70 of Set 1 | rawson
# Processing Record 71 of Set 1 | saskylakh
# Processing Record 72 of Set 1 | ocampo
# Processing Record 73 of Set 1 | jasidih
# Processing Record 74 of Set 1 | minot
# Processing Record 75 of Set 1 | vao
# Processing Record 76 of Set 1 | husavik
# Processing Record 77 of Set 1 | grand gaube
# Processing Record 78 of Set 1 | flinders
# Processing Record 79 of Set 1 | khatanga
# Processing Record 80 of Set 1 | hilo
# Processing Record 81 of Set 1 | northam
# Processing Record 82 of Set 1 | yumen
# Processing Record 83 of Set 1 | bichena
# Processing Record 84 of Set 1 | grand river south east
# ****Failed**** Processing Record 84 of Set 1 | grand river south east
# Processing Record 85 of Set 1 | cockburn town
# Processing Record 86 of Set 1 | mar del plata
# Processing Record 87 of Set 1 | saint-philippe
# Processing Record 88 of Set 1 | moose factory
# Processing Record 89 of Set 1 | caborca
# Processing Record 90 of Set 1 | hithadhoo
# Processing Record 91 of Set 1 | sao filipe
# Processing Record 92 of Set 1 | atuona
# Processing Record 93 of Set 1 | provideniya
# Processing Record 94 of Set 1 | leningradskiy
# Processing Record 95 of Set 1 | airai
# ****Failed**** Processing Record 95 of Set 1 | airai
# Processing Record 96 of Set 1 | port elizabeth
# Processing Record 97 of Set 1 | bambous virieux
# Processing Record 98 of Set 1 | hermanus
# Processing Record 99 of Set 1 | carnarvon
# Processing Record 100 of Set 1 | hay river
# Processing Record 101 of Set 1 | arraial do cabo
# Processing Record 102 of Set 1 | sribne
# Processing Record 103 of Set 1 | curico
# Processing Record 104 of Set 1 | baruun-urt
# Processing Record 105 of Set 1 | victoria
# Processing Record 106 of Set 1 | belushya guba
# ****Failed**** Processing Record 106 of Set 1 | belushya guba
# Processing Record 107 of Set 1 | gambita
# ****Failed**** Processing Record 107 of Set 1 | gambita
# Processing Record 108 of Set 1 | kapaa
# Processing Record 109 of Set 1 | bloemfontein
# Processing Record 110 of Set 1 | beachwood
# Processing Record 111 of Set 1 | umzimvubu
# ****Failed**** Processing Record 111 of Set 1 | umzimvubu
# Processing Record 112 of Set 1 | chuy
# Processing Record 113 of Set 1 | geraldton
# Processing Record 114 of Set 1 | vila velha
# Processing Record 115 of Set 1 | kirkland lake
# Processing Record 116 of Set 1 | ribeira grande
# Processing Record 117 of Set 1 | chicama
# Processing Record 118 of Set 1 | asekeyevo
# Processing Record 119 of Set 1 | hobart
# Processing Record 120 of Set 1 | georgetown
# Processing Record 121 of Set 1 | sao miguel do araguaia
# Processing Record 122 of Set 1 | bago
# Processing Record 123 of Set 1 | lebu
# Processing Record 124 of Set 1 | sibiti
# Processing Record 125 of Set 1 | qaqortoq
# Processing Record 126 of Set 1 | requena
# ****Failed**** Processing Record 126 of Set 1 | requena
# Processing Record 127 of Set 1 | mangrol
# Processing Record 128 of Set 1 | dzaoudzi
# Processing Record 129 of Set 1 | halifax
# Processing Record 130 of Set 1 | mancora
# Processing Record 131 of Set 1 | barentsburg
# ****Failed**** Processing Record 131 of Set 1 | barentsburg
# Processing Record 132 of Set 1 | chifeng
# Processing Record 133 of Set 1 | makat
# Processing Record 134 of Set 1 | floro
# Processing Record 135 of Set 1 | grand forks
# Processing Record 136 of Set 1 | camacha
# Processing Record 137 of Set 1 | yellowknife
# Processing Record 138 of Set 1 | yatou
# Processing Record 139 of Set 1 | rangpo
# Processing Record 140 of Set 1 | ulladulla
# Processing Record 141 of Set 1 | new norfolk
# Processing Record 142 of Set 1 | tsihombe
# ****Failed**** Processing Record 142 of Set 1 | tsihombe
# Processing Record 143 of Set 1 | samusu
# ****Failed**** Processing Record 143 of Set 1 | samusu
# Processing Record 144 of Set 1 | hanumangarh
# Processing Record 145 of Set 1 | severodvinsk
# Processing Record 146 of Set 1 | mexico
# Processing Record 147 of Set 1 | portland
# Processing Record 148 of Set 1 | jilin
# Processing Record 149 of Set 1 | rio tinto
# Processing Record 150 of Set 1 | falealupo
# ****Failed**** Processing Record 150 of Set 1 | falealupo
# Processing Record 151 of Set 1 | yarada
# Processing Record 152 of Set 1 | masuguru
# Processing Record 153 of Set 1 | bairiki
# ****Failed**** Processing Record 153 of Set 1 | bairiki
# Processing Record 154 of Set 1 | saint george
# Processing Record 155 of Set 1 | krasnaya gorka
# Processing Record 156 of Set 1 | severo-kurilsk
# Processing Record 157 of Set 1 | marsala
# Processing Record 158 of Set 1 | cherskiy
# Processing Record 159 of Set 1 | marzuq
# ****Failed**** Processing Record 159 of Set 1 | marzuq
# Processing Record 160 of Set 1 | maxixe
# Processing Record 161 of Set 1 | luderitz
# Processing Record 162 of Set 1 | taolanaro
# ****Failed**** Processing Record 162 of Set 1 | taolanaro
# Processing Record 163 of Set 1 | goderich
# ****Failed**** Processing Record 163 of Set 1 | goderich
# Processing Record 164 of Set 1 | hofn
# Processing Record 165 of Set 1 | mogadishu
# Processing Record 166 of Set 1 | mount isa
# Processing Record 167 of Set 1 | daru
# Processing Record 168 of Set 1 | butaritari
# Processing Record 169 of Set 1 | hasaki
# Processing Record 170 of Set 1 | toliary
# ****Failed**** Processing Record 170 of Set 1 | toliary
# Processing Record 171 of Set 1 | kampong chhnang
# Processing Record 172 of Set 1 | stara synyava
# Processing Record 173 of Set 1 | necochea
# Processing Record 174 of Set 1 | srednekolymsk
# Processing Record 175 of Set 1 | capitao poco
# Processing Record 176 of Set 1 | komsomolskiy
# Processing Record 177 of Set 1 | kloulklubed
# Processing Record 178 of Set 1 | olinda
# Processing Record 179 of Set 1 | ati
# Processing Record 180 of Set 1 | shimoda
# Processing Record 181 of Set 1 | nemuro
# Processing Record 182 of Set 1 | emirdag
# Processing Record 183 of Set 1 | sentyabrskiy
# ****Failed**** Processing Record 183 of Set 1 | sentyabrskiy
# Processing Record 184 of Set 1 | kaitangata
# Processing Record 185 of Set 1 | qaanaaq
# Processing Record 186 of Set 1 | saldanha
# Processing Record 187 of Set 1 | lompoc
# Processing Record 188 of Set 1 | amderma
# ****Failed**** Processing Record 188 of Set 1 | amderma
# Processing Record 189 of Set 1 | lasa
# ****Failed**** Processing Record 189 of Set 1 | lasa
# Processing Record 190 of Set 1 | cabo san lucas
# Processing Record 191 of Set 1 | kamina
# Processing Record 192 of Set 1 | pangoa
# Processing Record 193 of Set 1 | keetmanshoop
# Processing Record 194 of Set 1 | tukrah
# ****Failed**** Processing Record 194 of Set 1 | tukrah
# Processing Record 195 of Set 1 | sladkovo
# Processing Record 196 of Set 1 | mys shmidta
# ****Failed**** Processing Record 196 of Set 1 | mys shmidta
# Processing Record 197 of Set 1 | ngunguru
# Processing Record 198 of Set 1 | bengkulu
# ****Failed**** Processing Record 198 of Set 1 | bengkulu
# Processing Record 199 of Set 1 | bosobolo
# Processing Record 200 of Set 1 | la rioja
# Processing Record 201 of Set 1 | barrow
# Processing Record 202 of Set 1 | maryborough
# Processing Record 203 of Set 1 | ngukurr
# ****Failed**** Processing Record 203 of Set 1 | ngukurr
# Processing Record 204 of Set 1 | adrar
# Processing Record 205 of Set 1 | sao gabriel da cachoeira
# Processing Record 206 of Set 1 | clyde river
# Processing Record 207 of Set 1 | owando
# Processing Record 208 of Set 1 | port blair
# Processing Record 209 of Set 1 | pinotepa nacional
# ****Failed**** Processing Record 209 of Set 1 | pinotepa nacional
# Processing Record 210 of Set 1 | katsuura
# Processing Record 211 of Set 1 | dibulla
# Processing Record 212 of Set 1 | tabiauea
# ****Failed**** Processing Record 212 of Set 1 | tabiauea
# Processing Record 213 of Set 1 | berbera
# Processing Record 214 of Set 1 | zhigansk
# Processing Record 215 of Set 1 | la roche-sur-yon
# Processing Record 216 of Set 1 | arman
# Processing Record 217 of Set 1 | takestan
# Processing Record 218 of Set 1 | awbari
# Processing Record 219 of Set 1 | kaeo
# Processing Record 220 of Set 1 | vaitupu
# ****Failed**** Processing Record 220 of Set 1 | vaitupu
# Processing Record 221 of Set 1 | ostrovnoy
# Processing Record 222 of Set 1 | novoleushkovskaya
# Processing Record 223 of Set 1 | rocky mountain house
# Processing Record 224 of Set 1 | gurgan
# ****Failed**** Processing Record 224 of Set 1 | gurgan
# Processing Record 225 of Set 1 | dikson
# Processing Record 226 of Set 1 | olga
# Processing Record 227 of Set 1 | makung
# ****Failed**** Processing Record 227 of Set 1 | makung
# Processing Record 228 of Set 1 | asau
# ****Failed**** Processing Record 228 of Set 1 | asau
# Processing Record 229 of Set 1 | kieta
# Processing Record 230 of Set 1 | glazov
# Processing Record 231 of Set 1 | hami
# Processing Record 232 of Set 1 | almirante tamandare
# Processing Record 233 of Set 1 | nizhneyansk
# ****Failed**** Processing Record 233 of Set 1 | nizhneyansk
# Processing Record 234 of Set 1 | kembe
# Processing Record 235 of Set 1 | chokurdakh
# Processing Record 236 of Set 1 | wum
# Processing Record 237 of Set 1 | chengde
# Processing Record 238 of Set 1 | shinpokh
# Processing Record 239 of Set 1 | ambon
# Processing Record 240 of Set 1 | cairo
# Processing Record 241 of Set 1 | parrita
# Processing Record 242 of Set 1 | qabis
# ****Failed**** Processing Record 242 of Set 1 | qabis
# Processing Record 243 of Set 1 | lunavada
# Processing Record 244 of Set 1 | tumannyy
# ****Failed**** Processing Record 244 of Set 1 | tumannyy
# Processing Record 245 of Set 1 | jiamusi
# Processing Record 246 of Set 1 | riyadh
# Processing Record 247 of Set 1 | bani walid
# Processing Record 248 of Set 1 | leh
# Processing Record 249 of Set 1 | zarechnyy
# Processing Record 250 of Set 1 | chara
# Processing Record 251 of Set 1 | porto walter
# Processing Record 252 of Set 1 | bredasdorp
# Processing Record 253 of Set 1 | codrington
# ****Failed**** Processing Record 253 of Set 1 | codrington
# Processing Record 254 of Set 1 | mayumba
# Processing Record 255 of Set 1 | nanortalik
# Processing Record 256 of Set 1 | porto nacional
# Processing Record 257 of Set 1 | gigmoto
# Processing Record 258 of Set 1 | castro
# Processing Record 259 of Set 1 | kalmunai
# Processing Record 260 of Set 1 | ciro marina
# Processing Record 261 of Set 1 | mount gambier
# Processing Record 262 of Set 1 | buala
# Processing Record 263 of Set 1 | henties bay
# Processing Record 264 of Set 1 | hunza
# ****Failed**** Processing Record 264 of Set 1 | hunza
# Processing Record 265 of Set 1 | gudari
# Processing Record 266 of Set 1 | genhe
# Processing Record 267 of Set 1 | whitehorse
# Processing Record 268 of Set 1 | haines junction
# Processing Record 269 of Set 1 | moscow
# Processing Record 270 of Set 1 | talara
# Processing Record 271 of Set 1 | villiers
# Processing Record 272 of Set 1 | tuatapere
# Processing Record 273 of Set 1 | diego de almagro
# Processing Record 274 of Set 1 | ullapool
# Processing Record 275 of Set 1 | marcona
# ****Failed**** Processing Record 275 of Set 1 | marcona
# Processing Record 276 of Set 1 | guymon
# Processing Record 277 of Set 1 | haibowan
# ****Failed**** Processing Record 277 of Set 1 | haibowan
# Processing Record 278 of Set 1 | rozkishne
# Processing Record 279 of Set 1 | hambantota
# Processing Record 280 of Set 1 | fairbanks
# Processing Record 281 of Set 1 | lolua
# ****Failed**** Processing Record 281 of Set 1 | lolua
# Processing Record 282 of Set 1 | wenchi
# Processing Record 283 of Set 1 | namatanai
# Processing Record 284 of Set 1 | jiuquan
# Processing Record 285 of Set 1 | berdigestyakh
# Processing Record 286 of Set 1 | constitucion
# Processing Record 287 of Set 1 | murgab
# Processing Record 288 of Set 1 | warrnambool
# Processing Record 289 of Set 1 | zhaotong
# Processing Record 290 of Set 1 | sao joao da barra
# Processing Record 291 of Set 1 | vardo
# Processing Record 292 of Set 1 | pochutla
# Processing Record 293 of Set 1 | cidreira
# Processing Record 294 of Set 1 | faanui
# Processing Record 295 of Set 1 | kargopol
# Processing Record 296 of Set 1 | san quintin
# ****Failed**** Processing Record 296 of Set 1 | san quintin
# Processing Record 297 of Set 1 | kamenskoye
# ****Failed**** Processing Record 297 of Set 1 | kamenskoye
# Processing Record 298 of Set 1 | iquitos
# Processing Record 299 of Set 1 | batemans bay
# Processing Record 300 of Set 1 | namtsy
# Processing Record 301 of Set 1 | roma
# Processing Record 302 of Set 1 | kidal
# Processing Record 303 of Set 1 | sorong
# Processing Record 304 of Set 1 | strezhevoy
# Processing Record 305 of Set 1 | iqaluit
# Processing Record 306 of Set 1 | karratha
# Processing Record 307 of Set 1 | sumbawa
# ****Failed**** Processing Record 307 of Set 1 | sumbawa
# Processing Record 308 of Set 1 | goiatuba
# Processing Record 309 of Set 1 | nelson bay
# Processing Record 310 of Set 1 | hutchinson
# Processing Record 311 of Set 1 | belyy yar
# Processing Record 312 of Set 1 | paita
# Processing Record 313 of Set 1 | harqalah
# Processing Record 314 of Set 1 | nikolskoye
# Processing Record 315 of Set 1 | bud
# Processing Record 316 of Set 1 | kayunga
# Processing Record 317 of Set 1 | campbell river
# Processing Record 318 of Set 1 | gwadar
# Processing Record 319 of Set 1 | buchanan
# Processing Record 320 of Set 1 | gobabis
# Processing Record 321 of Set 1 | uren
# Processing Record 322 of Set 1 | vrangel
# Processing Record 323 of Set 1 | tadine
# Processing Record 324 of Set 1 | lagoa
# Processing Record 325 of Set 1 | barbar
# ****Failed**** Processing Record 325 of Set 1 | barbar
# Processing Record 326 of Set 1 | marsa matruh
# Processing Record 327 of Set 1 | loukhi
# Processing Record 328 of Set 1 | merauke
# Processing Record 329 of Set 1 | mackay
# Processing Record 330 of Set 1 | vanimo
# Processing Record 331 of Set 1 | formoso do araguaia
# ****Failed**** Processing Record 331 of Set 1 | formoso do araguaia
# Processing Record 332 of Set 1 | springfield
# Processing Record 333 of Set 1 | zelenets
# Processing Record 334 of Set 1 | novobiryusinskiy
# Processing Record 335 of Set 1 | barawe
# ****Failed**** Processing Record 335 of Set 1 | barawe
# Processing Record 336 of Set 1 | jumla
# Processing Record 337 of Set 1 | louisbourg
# ****Failed**** Processing Record 337 of Set 1 | louisbourg
# Processing Record 338 of Set 1 | sungaipenuh
# Processing Record 339 of Set 1 | half moon bay
# Processing Record 340 of Set 1 | mweka
# Processing Record 341 of Set 1 | pesaro
# Processing Record 342 of Set 1 | sampit
# Processing Record 343 of Set 1 | trapani
# Processing Record 344 of Set 1 | port-cartier
# Processing Record 345 of Set 1 | sommerda
# Processing Record 346 of Set 1 | shahreza
# Processing Record 347 of Set 1 | el alto
# ****Failed**** Processing Record 347 of Set 1 | el alto
# Processing Record 348 of Set 1 | lesosibirsk
# Processing Record 349 of Set 1 | mahaicony
# ****Failed**** Processing Record 349 of Set 1 | mahaicony
# Processing Record 350 of Set 1 | nhulunbuy
# Processing Record 351 of Set 1 | warri
# Processing Record 352 of Set 1 | grafton
# Processing Record 353 of Set 1 | benguela
# Processing Record 354 of Set 1 | agirish
# Processing Record 355 of Set 1 | alofi
# Processing Record 356 of Set 1 | kyaikkami
# Processing Record 357 of Set 1 | kichera
# Processing Record 358 of Set 1 | laguna
# ****Failed**** Processing Record 358 of Set 1 | laguna
# Processing Record 359 of Set 1 | pangai
# Processing Record 360 of Set 1 | itaituba
# Processing Record 361 of Set 1 | caravelas
# Processing Record 362 of Set 1 | montauban
# Processing Record 363 of Set 1 | pacific grove
# Processing Record 364 of Set 1 | canora
# Processing Record 365 of Set 1 | gat
# ****Failed**** Processing Record 365 of Set 1 | gat
# Processing Record 366 of Set 1 | poum
# Processing Record 367 of Set 1 | muli
# Processing Record 368 of Set 1 | kyritz
# Processing Record 369 of Set 1 | ostersund
# Processing Record 370 of Set 1 | kirakira
# Processing Record 371 of Set 1 | the valley
# Processing Record 372 of Set 1 | soyo
# Processing Record 373 of Set 1 | talnakh
# Processing Record 374 of Set 1 | challans
# Processing Record 375 of Set 1 | itarema
# Processing Record 376 of Set 1 | rio grande
# Processing Record 377 of Set 1 | sinnamary
# Processing Record 378 of Set 1 | hovd
# Processing Record 379 of Set 1 | baherden
# Processing Record 380 of Set 1 | saint-paul
# Processing Record 381 of Set 1 | mugumu
# Processing Record 382 of Set 1 | bubaque
# Processing Record 383 of Set 1 | san patricio
# Processing Record 384 of Set 1 | lasem
# Processing Record 385 of Set 1 | killin
# ****Failed**** Processing Record 385 of Set 1 | killin
# Processing Record 386 of Set 1 | lethem
# Processing Record 387 of Set 1 | kobojango
# ****Failed**** Processing Record 387 of Set 1 | kobojango
# Processing Record 388 of Set 1 | medicine hat
# Processing Record 389 of Set 1 | norman wells
# Processing Record 390 of Set 1 | arlit
# Processing Record 391 of Set 1 | bathsheba
# Processing Record 392 of Set 1 | patti
# Processing Record 393 of Set 1 | stuttgart
# Processing Record 394 of Set 1 | porto santo
# Processing Record 395 of Set 1 | awjilah
# Processing Record 396 of Set 1 | blonduos
# ****Failed**** Processing Record 396 of Set 1 | blonduos
# Processing Record 397 of Set 1 | pyu
# Processing Record 398 of Set 1 | wallaceburg
# Processing Record 399 of Set 1 | kidodi
# Processing Record 400 of Set 1 | wanning
# Processing Record 401 of Set 1 | dhidhdhoo
# Processing Record 402 of Set 1 | carballo
# Processing Record 403 of Set 1 | montanha
# Processing Record 404 of Set 1 | namibe
# Processing Record 405 of Set 1 | kahului
# Processing Record 406 of Set 1 | mehamn
# Processing Record 407 of Set 1 | port hedland
# Processing Record 408 of Set 1 | mergui
# ****Failed**** Processing Record 408 of Set 1 | mergui
# Processing Record 409 of Set 1 | sobolevo
# Processing Record 410 of Set 1 | beloha
# Processing Record 411 of Set 1 | notodden
# Processing Record 412 of Set 1 | tobolsk
# Processing Record 413 of Set 1 | puerto escondido
# Processing Record 414 of Set 1 | luena
# Processing Record 415 of Set 1 | omboue
# Processing Record 416 of Set 1 | araouane
# Processing Record 417 of Set 1 | dunedin
# Processing Record 418 of Set 1 | nouadhibou
# Processing Record 419 of Set 1 | kapit
# Processing Record 420 of Set 1 | ilulissat
# Processing Record 421 of Set 1 | atar
# Processing Record 422 of Set 1 | griffith
# Processing Record 423 of Set 1 | san policarpo
# Processing Record 424 of Set 1 | idah
# Processing Record 425 of Set 1 | virginia beach
# Processing Record 426 of Set 1 | salalah
# Processing Record 427 of Set 1 | qianguo
# Processing Record 428 of Set 1 | date
# Processing Record 429 of Set 1 | douglas
# Processing Record 430 of Set 1 | obodivka
# Processing Record 431 of Set 1 | ashland
# Processing Record 432 of Set 1 | yurya
# ****Failed**** Processing Record 432 of Set 1 | yurya
# Processing Record 433 of Set 1 | kelc
# Processing Record 434 of Set 1 | sidi ali
# Processing Record 435 of Set 1 | redlands
# Processing Record 436 of Set 1 | temerloh
# Processing Record 437 of Set 1 | chikoy
# ****Failed**** Processing Record 437 of Set 1 | chikoy
# Processing Record 438 of Set 1 | ghauspur
# Processing Record 439 of Set 1 | noyabrsk
# Processing Record 440 of Set 1 | hirara
# Processing Record 441 of Set 1 | kudahuvadhoo
# Processing Record 442 of Set 1 | bengkalis
# ****Failed**** Processing Record 442 of Set 1 | bengkalis
# Processing Record 443 of Set 1 | moerai
# Processing Record 444 of Set 1 | alta floresta
# Processing Record 445 of Set 1 | maslovare
# Processing Record 446 of Set 1 | nabire
# Processing Record 447 of Set 1 | bor
# Processing Record 448 of Set 1 | shilong
# Processing Record 449 of Set 1 | vostok
# Processing Record 450 of Set 1 | isangel
# Processing Record 451 of Set 1 | padang
# Processing Record 452 of Set 1 | bayan
# Processing Record 453 of Set 1 | sitka
# Processing Record 454 of Set 1 | caucaia
# Processing Record 455 of Set 1 | kuche
# ****Failed**** Processing Record 455 of Set 1 | kuche
# Processing Record 456 of Set 1 | kolondieba
# Processing Record 457 of Set 1 | santa maria
# Processing Record 458 of Set 1 | bulakamba
# Processing Record 459 of Set 1 | neuquen
# Processing Record 460 of Set 1 | khrustalnyy
# ****Failed**** Processing Record 460 of Set 1 | khrustalnyy
# Processing Record 461 of Set 1 | potam
# Processing Record 462 of Set 1 | carleton place
# Processing Record 463 of Set 1 | krasavino
# Processing Record 464 of Set 1 | aklavik
# Processing Record 465 of Set 1 | cayenne
# Processing Record 466 of Set 1 | bandarbeyla
# Processing Record 467 of Set 1 | mortka
# Processing Record 468 of Set 1 | banda aceh
# Processing Record 469 of Set 1 | alekseyevskoye
# Processing Record 470 of Set 1 | aviles
# Processing Record 471 of Set 1 | sabha
# Processing Record 472 of Set 1 | impfondo
# Processing Record 473 of Set 1 | tulun
# Processing Record 474 of Set 1 | yerbogachen
# Processing Record 475 of Set 1 | pevek
# Processing Record 476 of Set 1 | castries
# Processing Record 477 of Set 1 | warqla
# ****Failed**** Processing Record 477 of Set 1 | warqla
# Processing Record 478 of Set 1 | belmonte
# Processing Record 479 of Set 1 | sept-iles
# Processing Record 480 of Set 1 | los llanos de aridane
# Processing Record 481 of Set 1 | erzin
# Processing Record 482 of Set 1 | tabuk
# Processing Record 483 of Set 1 | calama
# Processing Record 484 of Set 1 | kulhudhuffushi
# Processing Record 485 of Set 1 | qidong
# Processing Record 486 of Set 1 | esperance
# Processing Record 487 of Set 1 | taltal
# Processing Record 488 of Set 1 | sao luis de montes belos
# Processing Record 489 of Set 1 | kavieng
# Processing Record 490 of Set 1 | kimparana
# Processing Record 491 of Set 1 | manggar
# Processing Record 492 of Set 1 | la ronge
# Processing Record 493 of Set 1 | kodinsk
# Processing Record 494 of Set 1 | yevlax
# Processing Record 495 of Set 1 | burica
# ****Failed**** Processing Record 495 of Set 1 | burica
# Processing Record 496 of Set 1 | itamaraju
# Processing Record 497 of Set 1 | port lincoln
# Processing Record 498 of Set 1 | langsa
# Processing Record 499 of Set 1 | tandil
# Processing Record 500 of Set 1 | revelstoke
# Processing Record 501 of Set 1 | sassandra
# Processing Record 502 of Set 1 | jahrom
# ****Failed**** Processing Record 502 of Set 1 | jahrom
# Processing Record 503 of Set 1 | mandurah
# Processing Record 504 of Set 1 | pangody
# Processing Record 505 of Set 1 | banska stiavnica
# Processing Record 506 of Set 1 | san jose
# Processing Record 507 of Set 1 | saraikela
# Processing Record 508 of Set 1 | vila franca do campo
# Processing Record 509 of Set 1 | sungairaya
# Processing Record 510 of Set 1 | petauke
# Processing Record 511 of Set 1 | nishihara
# Processing Record 512 of Set 1 | skjold
# Processing Record 513 of Set 1 | sorvag
# ****Failed**** Processing Record 513 of Set 1 | sorvag
# Processing Record 514 of Set 1 | zhongshu
# Processing Record 515 of Set 1 | santiago de cao
# Processing Record 516 of Set 1 | sangar
# Processing Record 517 of Set 1 | launceston
# Processing Record 518 of Set 1 | ambilobe
# Processing Record 519 of Set 1 | ancud
# Processing Record 520 of Set 1 | bacuit
# ****Failed**** Processing Record 520 of Set 1 | bacuit
# Processing Record 521 of Set 1 | makakilo city
# Processing Record 522 of Set 1 | calvinia
# Processing Record 523 of Set 1 | evensk
# Processing Record 524 of Set 1 | iwanai
# Processing Record 525 of Set 1 | ahuimanu
# Processing Record 526 of Set 1 | helong
# Processing Record 527 of Set 1 | isla mujeres
# Processing Record 528 of Set 1 | bagli
# Processing Record 529 of Set 1 | charlestown
# Processing Record 530 of Set 1 | avera
# ****Failed**** Processing Record 530 of Set 1 | avera
# Processing Record 531 of Set 1 | macaboboni
# ****Failed**** Processing Record 531 of Set 1 | macaboboni
# Processing Record 532 of Set 1 | cattolica
# Processing Record 533 of Set 1 | tuggurt
# ****Failed**** Processing Record 533 of Set 1 | tuggurt
# Processing Record 534 of Set 1 | saint anthony
# ****Failed**** Processing Record 534 of Set 1 | saint anthony
# Processing Record 535 of Set 1 | provost
# Processing Record 536 of Set 1 | bonaventure
# Processing Record 537 of Set 1 | axim
# Processing Record 538 of Set 1 | colares
# Processing Record 539 of Set 1 | roald
# Processing Record 540 of Set 1 | camana
# ****Failed**** Processing Record 540 of Set 1 | camana
# Processing Record 541 of Set 1 | broome
# Processing Record 542 of Set 1 | tselinnoye
# ****Failed**** Processing Record 542 of Set 1 | tselinnoye
# Processing Record 543 of Set 1 | nantucket
# Processing Record 544 of Set 1 | aguimes
# Processing Record 545 of Set 1 | tshela
# Processing Record 546 of Set 1 | vammala
# Processing Record 547 of Set 1 | miri
# Processing Record 548 of Set 1 | kuytun
# Processing Record 549 of Set 1 | vestmannaeyjar
# Processing Record 550 of Set 1 | salto del guaira
# Processing Record 551 of Set 1 | leua
# Processing Record 552 of Set 1 | chapais
# Processing Record 553 of Set 1 | santiago
# Processing Record 554 of Set 1 | itoman
# Processing Record 555 of Set 1 | port shepstone
# Processing Record 556 of Set 1 | yanchukan
# ****Failed**** Processing Record 556 of Set 1 | yanchukan
# Processing Record 557 of Set 1 | tilichiki
# Processing Record 558 of Set 1 | vestmanna
# Processing Record 559 of Set 1 | kamennogorsk
# Processing Record 560 of Set 1 | inta
# Processing Record 561 of Set 1 | mahon
# ****Failed**** Processing Record 561 of Set 1 | mahon
# Processing Record 562 of Set 1 | stekolnyy
# ****Failed**** Processing Record 562 of Set 1 | stekolnyy
# Processing Record 563 of Set 1 | dolbeau
# ****Failed**** Processing Record 563 of Set 1 | dolbeau
# Processing Record 564 of Set 1 | dingle
# Processing Record 565 of Set 1 | pisco
# Processing Record 566 of Set 1 | korla
# Processing Record 567 of Set 1 | borazjan
# Processing Record 568 of Set 1 | rio de janeiro
# Processing Record 569 of Set 1 | bestobe
# Processing Record 570 of Set 1 | charters towers
# Processing Record 571 of Set 1 | urucara
# Processing Record 572 of Set 1 | palmer
# Processing Record 573 of Set 1 | lorengau
# Processing Record 574 of Set 1 | ixtapa
# Processing Record 575 of Set 1 | hundested
# Processing Record 576 of Set 1 | egvekinot
# Processing Record 577 of Set 1 | anadyr
# Processing Record 578 of Set 1 | rocha
# Processing Record 579 of Set 1 | san francisco del mar
# Processing Record 580 of Set 1 | yanam
# Processing Record 581 of Set 1 | le port
# Processing Record 582 of Set 1 | ormara
# Processing Record 583 of Set 1 | kuusamo
# Processing Record 584 of Set 1 | saurimo
# Processing Record 585 of Set 1 | wembley
# Processing Record 586 of Set 1 | svetlogorsk
# Processing Record 587 of Set 1 | inhambane
# Processing Record 588 of Set 1 | richards bay
# Processing Record 589 of Set 1 | shingu
# Processing Record 590 of Set 1 | lagos
# Processing Record 591 of Set 1 | nador
# Processing Record 592 of Set 1 | santa cruz
# Processing Record 593 of Set 1 | bowen
# Processing Record 594 of Set 1 | new kensington
# Processing Record 595 of Set 1 | kavaratti
# Processing Record 596 of Set 1 | poshekhonye
# Processing Record 597 of Set 1 | kirkenaer

# %%
data1 = {"City": error_cities, "Country": error_countries, "Error Code": error_code}
error_df = pd.DataFrame(data1) 
error_df.to_csv(r'ErredRows_Geetha.csv')
error_df
# Out:
#                       City Country  \
# 0             attawapiskat      ca
# 1                 saleaula      ws
# 2                   chagda      ru
# 3                  mataura      pf
# 4         illoqqortoormiut      gl
# 5   grand river south east      mu
# 6                    airai      pw
# 7            belushya guba      ru
# 8                  gambita      co
# 9                umzimvubu      za
# 10                 requena      pe
# 11             barentsburg      sj
# 12                tsihombe      mg
# 13                  samusu      ws
# 14               falealupo      ws
# 15                 bairiki      ki
# 16                  marzuq      ly
# 17               taolanaro      mg
# 18                goderich      sl
# 19                 toliary      mg
# 20            sentyabrskiy      ru
# 21                 amderma      ru
# 22                    lasa      cn
# 23                  tukrah      ly
# 24             mys shmidta      ru
# 25                bengkulu      id
# 26                 ngukurr      au
# 27       pinotepa nacional      mx
# 28                tabiauea      ki
# 29                 vaitupu      wf
# ..                     ...     ...
# 46                  barawe      so
# 47              louisbourg      ca
# 48                 el alto      pe
# 49               mahaicony      gy
# 50                  laguna      br
# 51                     gat      ly
# 52                  killin      gb
# 53               kobojango      bw
# 54                blonduos      is
# 55                  mergui      mm
# 56                   yurya      ru
# 57                  chikoy      ru
# 58               bengkalis      id
# 59                   kuche      cn
# 60             khrustalnyy      ru
# 61                  warqla      dz
# 62                  burica      pa
# 63                  jahrom      ir
# 64                  sorvag      fo
# 65                  bacuit      ph
# 66                   avera      pf
# 67              macaboboni      ph
# 68                 tuggurt      dz
# 69           saint anthony      ca
# 70                  camana      pe
# 71              tselinnoye      ru
# 72               yanchukan      ru
# 73                   mahon      es
# 74               stekolnyy      ru
# 75                 dolbeau      ca
#
#                                      Error Code
# 0   {'cod': '404', 'message': 'city not found'}
# 1   {'cod': '404', 'message': 'city not found'}
# 2   {'cod': '404', 'message': 'city not found'}
# 3   {'cod': '404', 'message': 'city not found'}
# 4   {'cod': '404', 'message': 'city not found'}
# 5   {'cod': '404', 'message': 'city not found'}
# 6   {'cod': '404', 'message': 'city not found'}
# 7   {'cod': '404', 'message': 'city not found'}
# 8   {'cod': '404', 'message': 'city not found'}
# 9   {'cod': '404', 'message': 'city not found'}
# 10  {'cod': '404', 'message': 'city not found'}
# 11  {'cod': '404', 'message': 'city not found'}
# 12  {'cod': '404', 'message': 'city not found'}
# 13  {'cod': '404', 'message': 'city not found'}
# 14  {'cod': '404', 'message': 'city not found'}
# 15  {'cod': '404', 'message': 'city not found'}
# 16  {'cod': '404', 'message': 'city not found'}
# 17  {'cod': '404', 'message': 'city not found'}
# 18  {'cod': '404', 'message': 'city not found'}
# 19  {'cod': '404', 'message': 'city not found'}
# 20  {'cod': '404', 'message': 'city not found'}
# 21  {'cod': '404', 'message': 'city not found'}
# 22  {'cod': '404', 'message': 'city not found'}
# 23  {'cod': '404', 'message': 'city not found'}
# 24  {'cod': '404', 'message': 'city not found'}
# 25  {'cod': '404', 'message': 'city not found'}
# 26  {'cod': '404', 'message': 'city not found'}
# 27  {'cod': '404', 'message': 'city not found'}
# 28  {'cod': '404', 'message': 'city not found'}
# 29  {'cod': '404', 'message': 'city not found'}
# ..                                          ...
# 46  {'cod': '404', 'message': 'city not found'}
# 47  {'cod': '404', 'message': 'city not found'}
# 48  {'cod': '404', 'message': 'city not found'}
# 49  {'cod': '404', 'message': 'city not found'}
# 50  {'cod': '404', 'message': 'city not found'}
# 51  {'cod': '404', 'message': 'city not found'}
# 52  {'cod': '404', 'message': 'city not found'}
# 53  {'cod': '404', 'message': 'city not found'}
# 54  {'cod': '404', 'message': 'city not found'}
# 55  {'cod': '404', 'message': 'city not found'}
# 56  {'cod': '404', 'message': 'city not found'}
# 57  {'cod': '404', 'message': 'city not found'}
# 58  {'cod': '404', 'message': 'city not found'}
# 59  {'cod': '404', 'message': 'city not found'}
# 60  {'cod': '404', 'message': 'city not found'}
# 61  {'cod': '404', 'message': 'city not found'}
# 62  {'cod': '404', 'message': 'city not found'}
# 63  {'cod': '404', 'message': 'city not found'}
# 64  {'cod': '404', 'message': 'city not found'}
# 65  {'cod': '404', 'message': 'city not found'}
# 66  {'cod': '404', 'message': 'city not found'}
# 67  {'cod': '404', 'message': 'city not found'}
# 68  {'cod': '404', 'message': 'city not found'}
# 69  {'cod': '404', 'message': 'city not found'}
# 70  {'cod': '404', 'message': 'city not found'}
# 71  {'cod': '404', 'message': 'city not found'}
# 72  {'cod': '404', 'message': 'city not found'}
# 73  {'cod': '404', 'message': 'city not found'}
# 74  {'cod': '404', 'message': 'city not found'}
# 75  {'cod': '404', 'message': 'city not found'}
#
# [76 rows x 3 columns]

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
data = {"City ID": ID_df, "City": city_df, "Cloudiness": cloud_df, "Country": country_df, "Date": date_df, "Humidity": humidity_df, "Lat": lat_df, "Lng": lon_df, "Max Temp": maxtemp_df, "Wind Speed": wind_df}
weather_df = pd.DataFrame(data) 
weather_df.head()
weather_df.to_csv(r'Weather_Geetha.csv')

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
x = weather_df["Lat"].values
y = weather_df["Max Temp"].values

plt.scatter(x, y,c="skyblue",linewidth=.5, edgecolors="black")

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.title("City Latitude vs Max Temperature")

plt.grid(True)
plt.show()

# Save Figure
from io import BytesIO
f = BytesIO()
plt.savefig(f, format="svg")

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
x = weather_df["Lat"].values
y = weather_df["Humidity"].values

plt.scatter(x, y,c="skyblue",linewidth=.5, edgecolors="black")

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.title("City Latitude vs Humidity")

plt.grid(True)
plt.show()

# Save Figure
from io import BytesIO
f = BytesIO()
plt.savefig(f, format="svg")

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
x = weather_df["Lat"].values
y = weather_df["Cloudiness"].values

plt.scatter(x, y,c="skyblue",linewidth=.5, edgecolors="black")

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.title("City Latitude vs Cloudiness")

plt.grid(True)
plt.show()

# Save Figure
from io import BytesIO
f = BytesIO()
plt.savefig(f, format="svg")

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
x = weather_df["Lat"].values
y = weather_df["Wind Speed"].values

plt.scatter(x, y,c="skyblue",linewidth=.5, edgecolors="black")

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.title("City Latitude vs Wind Speed")

plt.grid(True)
plt.show()

# Save Figure
from io import BytesIO
f = BytesIO()
plt.savefig(f, format="svg")
